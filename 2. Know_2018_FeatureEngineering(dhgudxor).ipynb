# %%
import optuna
import warnings
import gc
import os
import random
import sys

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from datetime import datetime
from glob import glob
from tqdm import tqdm

warnings.filterwarnings(action = 'ignore')

# %%
train_2017 = []
train_2018 = []
train_2019 = []
train_2020 = []

for i, path in enumerate(sorted(glob("Data/train/1.preprocessing_*.csv"))):
    if i == 0:
        train_2017 = pd.read_csv(path)
        pass
    elif i==1:
        train_2018 = pd.read_csv(path)
        pass
    elif i==2:
        train_2019 = pd.read_csv(path)
        pass
    else:
        train_2020 = pd.read_csv(path)
        pass
    
test_2017 = []
test_2018 = []
test_2019 = []
test_2020 = []

for i, path in enumerate(sorted(glob("Data/test/1.preprocessing_*.csv"))):
    if i == 0:
        test_2017 = pd.read_csv(path)
        pass
    elif i==1:
        test_2018 = pd.read_csv(path)
        pass
    elif i==2:
        test_2019 = pd.read_csv(path)
        pass
    else:
        test_2020 = pd.read_csv(path)
        pass

# %%
train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(' ', '')
train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(')', '')
train_2018['bq5_2'] = train_2018['bq5_2'].str.replace('(', '')
train_2018['bq5_2'] = train_2018['bq5_2'].str.replace('+', '')
train_2018['bq5_2'] = train_2018['bq5_2'].str.replace('*', '')

# %%
for values in tqdm(train_2018['bq5_2']):
    if '3D' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '3D')
    elif 'CAD' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, 'CAD')
    elif 'CS' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, 'CS')
    elif 'IT' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, 'IT')
    elif 'SW' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, 'SW')
    elif '가공' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '가공')
    elif '가르치' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '강의')
    elif '가죽' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '가죽')
    elif '간호' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '간호')
    elif '감사' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '감사')
    elif '감염' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '감염')
    elif '강의' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '강의')
    elif '개발' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, 'SW')   
    elif '건설' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '건설')   
    elif '건축' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '건설')   
    elif '경영' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '경영')   
    elif '경제' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '경제')
    elif '고객' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '고객')
    elif '공연' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '공연')
    elif '관세' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '관세')
    elif '광고' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '광고')
    elif '교수' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '교수')
    elif '교육' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '교육')
    elif '교통' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '교통')
    elif '국제' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '국제')
    elif '군사' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '군사')
    elif '그래픽' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '그래픽')
    elif '금속' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '금속')
    elif '금융' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '금융')
    elif '기계' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '기계')
    elif '기록' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '기록')   
    elif '기획' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '기획')   
    elif '네트워크' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '네트워크')   
    elif '놀이' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '놀이')   
    elif '농기계' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '농기계')
    elif '농업' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '농기계')
    elif '뉴스' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '뉴스')
        
    elif '대본' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '대본')
    elif '데이터' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '데이터')
    elif '도면' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '도면')
    elif '도장' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '도장')
    elif '동물' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '동물')
    elif '디자인' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '디자인')
    elif '레지던트' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '레지던트')
    elif '로봇' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '로봇')
    elif '마술' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '마술')
    elif '마케팅' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '마케팅')
    elif '무대' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '무대') # ㅁ에서 끝남
    elif '회계' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '회계')   
    elif '환자' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '간호사')   
    elif '화학' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '화학')   
    elif '화술' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '화술')   
    elif '화물' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '화물')
    elif '호흡' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '호흡')
    elif '항공' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '항공기')
    elif '학생' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '학생')
    elif '피부' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '피부')
    elif '프로그' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '프로그')
    elif '풍력' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '풍력')
    elif '품질' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '품질')
    elif '표준어' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '표준어') 
    elif '포토샵' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '포토샵')   
    elif '편집' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '편집')   
    elif '판매' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '판매')   
    elif '통신' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '통신')   
    elif '통관' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '통관')
    elif '통계' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '통계')
    elif '컷트' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '미용')

    elif '컴퓨터' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '컴퓨터')
    elif '커피' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '커피')
    elif '캐드' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, 'CAD')
    elif '카메라' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '카메라')
    elif '치아' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '치아')
    elif '치과' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '치아') 
    elif '치료' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '치료')   
    elif '취재' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '취재')   
    elif '출판' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '출판')   
    elif '촬영' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '촬영')   
    elif '체력' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '체력')
    elif '철도' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '철도')
    elif '채권' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '채권')
    elif '진단' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '진단')
    elif '지리' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '지리')
    elif '조리' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '조리')
    elif '제품' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '제품') 
    elif '제조' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '제조')   
    elif '정비' in values: 
        train_2018['bq5_2' ] = train_2018['bq5_2'].str.replace(values, '정비')   # ㅈ에서 끝남
    elif '전자' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '전자')   
    elif '전산' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '전산')   
    elif '전기' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '전기')
    elif '정비' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '정비')
    elif '자동차' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '자동차')
    elif '임상' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '임상')
    elif '의학' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '의학')
    elif '의사' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '의학')
    elif '의료' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '의학') 
    elif '응급' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '응급')   
    elif '음악' in values: 
        train_2018['bq5_2' ] = train_2018['bq5_2'].str.replace(values, '음반')
    elif '음반' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '음반')   
    elif '유아' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '유아')   
    elif '운항' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '운항')
    elif '용접' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '용접')
    elif '외국어' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '외국어')
    elif '영어' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '외국어')
    elif '영상' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '영상')
    elif '연예인' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '연예인')
    elif '연구' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '연구')
    elif '엑셀' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '엑셀') 
    elif '심리' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '심리')   
    elif '시스템' in values: 
        train_2018['bq5_2' ] = train_2018['bq5_2'].str.replace(values, '시스템')
    elif '시설물' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '시설물')   
    elif '습작' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '습작')   
    elif '숙련공' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '숙련공')
    elif '수질' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '수질')
    elif '문서' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '문서')        
    elif '문제' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '문제')
    elif '문화' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '문화')
    elif '미용' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '미용')
    elif '발성' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '발음')
    elif '발음' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '발음') 
    elif '방송' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '방송')   
    elif '법령' in values: 
        train_2018['bq5_2' ] = train_2018['bq5_2'].str.replace(values, '법률')
    elif '법률' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '법률')   
    elif '법정' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '법정')   
    elif '보석' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '보석')
    elif '보안' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '보안')
    elif '보험' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '보험')
    elif '부동산' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '부동산')
    elif '비파괴' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '비파괴')
    elif '사법' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '사법')
    elif '사진' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '사진')
    elif '산업안전' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '산업안전') 
    elif '상담' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '상담')   
    elif '상품' in values: 
        train_2018['bq5_2' ] = train_2018['bq5_2'].str.replace(values, '상품')
    elif '석사' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '석사')   
    elif '섬유' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '섬유')   
    elif '세법' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '세법')
    elif '세포' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '세포')
    elif '소방' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '소방')        
    elif '소프트웨어' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '소프트웨어')
    elif '수업' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '수업')
    elif '현장' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '현장')        
    elif '실무' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '실무')
    elif '관제' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '관제')   
    elif '세무' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '세무')   
    elif '실험기기' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '실험실습')
    elif '실헙실습' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '실험실습')
    elif '잠수' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '잠수')        
    elif '재봉틀' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '재봉틀')
    elif '컨설팅' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '컨설팅')
    elif '크레인' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '크레인')        
    elif '타일' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '타일')
    elif '토목' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '토목')   
    elif '행정' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '행정')   
    elif '화재' in values:
        train_2018['bq5_2'] = train_2018['bq5_2'].str.replace(values, '화재')
# Out:
# 100%|██████████| 9072/9072 [00:19<00:00, 455.44it/s]

# %%
for col in train_2018['bq5_2'].value_counts().loc[train_2018['bq5_2'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq5_2'] == col, 'bq5_2' + col] = 1
    train_2018 = train_2018.fillna(0)

for col in train_2018['bq5_2'].value_counts().loc[train_2018['bq5_2'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq5_2'] == col, 'bq5_2_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(' ', '')
test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(')', '')
test_2018['bq5_2'] = test_2018['bq5_2'].str.replace('(', '')
test_2018['bq5_2'] = test_2018['bq5_2'].str.replace('+', '')
test_2018['bq5_2'] = test_2018['bq5_2'].str.replace('*', '')

# %%
for values in tqdm(test_2018['bq5_2']):
    if '3D' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '3D')
    elif 'CAD' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, 'CAD')
    elif 'CS' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, 'CS')
    elif 'IT' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, 'IT')
    elif 'SW' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, 'SW')
    elif '가공' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '가공')
    elif '가르치' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '강의')
    elif '가죽' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '가죽')
    elif '간호' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '간호')
    elif '감사' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '감사')
    elif '감염' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '감염')
    elif '강의' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '강의')
    elif '개발' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, 'SW')   
    elif '건설' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '건설')   
    elif '건축' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '건설')   
    elif '경영' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '경영')   
    elif '경제' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '경제')
    elif '고객' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '고객')
    elif '공연' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '공연')
    elif '관세' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '관세')
    elif '광고' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '광고')
    elif '교수' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '교수')
    elif '교육' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '교육')
    elif '교통' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '교통')
    elif '국제' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '국제')
    elif '군사' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '군사')
    elif '그래픽' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '그래픽')
    elif '금속' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '금속')
    elif '금융' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '금융')
    elif '기계' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '기계')
    elif '기록' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '기록')   
    elif '기획' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '기획')   
    elif '네트워크' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '네트워크')   
    elif '놀이' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '놀이')   
    elif '농기계' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '농기계')
    elif '농업' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '농기계')
    elif '뉴스' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '뉴스')
        
    elif '대본' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '대본')
    elif '데이터' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '데이터')
    elif '도면' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '도면')
    elif '도장' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '도장')
    elif '동물' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '동물')
    elif '디자인' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '디자인')
    elif '레지던트' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '레지던트')
    elif '로봇' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '로봇')
    elif '마술' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '마술')
    elif '마케팅' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '마케팅')
    elif '무대' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '무대') # ㅁ에서 끝남
    elif '회계' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '회계')   
    elif '환자' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '간호사')   
    elif '화학' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '화학')   
    elif '화술' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '화술')   
    elif '화물' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '화물')
    elif '호흡' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '호흡')
    elif '항공' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '항공기')
    elif '학생' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '학생')
    elif '피부' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '피부')
    elif '프로그' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '프로그')
    elif '풍력' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '풍력')
    elif '품질' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '품질')
    elif '표준어' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '표준어') 
    elif '포토샵' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '포토샵')   
    elif '편집' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '편집')   
    elif '판매' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '판매')   
    elif '통신' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '통신')   
    elif '통관' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '통관')
    elif '통계' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '통계')
    elif '컷트' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '미용')

    elif '컴퓨터' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '컴퓨터')
    elif '커피' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '커피')
    elif '캐드' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, 'CAD')
    elif '카메라' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '카메라')
    elif '치아' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '치아')
    elif '치과' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '치아') 
    elif '치료' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '치료')   
    elif '취재' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '취재')   
    elif '출판' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '출판')   
    elif '촬영' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '촬영')   
    elif '체력' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '체력')
    elif '철도' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '철도')
    elif '채권' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '채권')
    elif '진단' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '진단')
    elif '지리' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '지리')
    elif '조리' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '조리')
    elif '제품' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '제품') 
    elif '제조' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '제조')   
    elif '정비' in values: 
        test_2018['bq5_2' ] = test_2018['bq5_2'].str.replace(values, '정비')   # ㅈ에서 끝남
    elif '전자' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '전자')   
    elif '전산' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '전산')   
    elif '전기' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '전기')
    elif '정비' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '정비')
    elif '자동차' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '자동차')
    elif '임상' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '임상')
    elif '의학' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '의학')
    elif '의사' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '의학')
    elif '의료' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '의학') 
    elif '응급' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '응급')   
    elif '음악' in values: 
        test_2018['bq5_2' ] = test_2018['bq5_2'].str.replace(values, '음반')
    elif '음반' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '음반')   
    elif '유아' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '유아')   
    elif '운항' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '운항')
    elif '용접' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '용접')
    elif '외국어' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '외국어')
    elif '영어' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '외국어')
    elif '영상' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '영상')
    elif '연예인' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '연예인')
    elif '연구' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '연구')
    elif '엑셀' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '엑셀') 
    elif '심리' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '심리')   
    elif '시스템' in values: 
        test_2018['bq5_2' ] = test_2018['bq5_2'].str.replace(values, '시스템')
    elif '시설물' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '시설물')   
    elif '습작' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '습작')   
    elif '숙련공' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '숙련공')
    elif '수질' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '수질')
    elif '문서' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '문서')        
    elif '문제' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '문제')
    elif '문화' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '문화')
    elif '미용' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '미용')
    elif '발성' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '발음')
    elif '발음' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '발음') 
    elif '방송' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '방송')   
    elif '법령' in values: 
        test_2018['bq5_2' ] = test_2018['bq5_2'].str.replace(values, '법률')
    elif '법률' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '법률')   
    elif '법정' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '법정')   
    elif '보석' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '보석')
    elif '보안' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '보안')
    elif '보험' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '보험')
    elif '부동산' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '부동산')
    elif '비파괴' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '비파괴')
    elif '사법' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '사법')
    elif '사진' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '사진')
    elif '산업안전' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '산업안전') 
    elif '상담' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '상담')   
    elif '상품' in values: 
        test_2018['bq5_2' ] = test_2018['bq5_2'].str.replace(values, '상품')
    elif '석사' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '석사')   
    elif '섬유' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '섬유')   
    elif '세법' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '세법')
    elif '세포' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '세포')
    elif '소방' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '소방')        
    elif '소프트웨어' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '소프트웨어')
    elif '수업' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '수업')
    elif '현장' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '현장')        
    elif '실무' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '실무')
    elif '관제' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '관제')   
    elif '세무' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '세무')   
    elif '실험기기' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '실험실습')
    elif '실헙실습' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '실험실습')
    elif '잠수' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '잠수')        
    elif '재봉틀' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '재봉틀')
    elif '컨설팅' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '컨설팅')
    elif '크레인' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '크레인')        
    elif '타일' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '타일')
    elif '토목' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '토목')   
    elif '행정' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '행정')   
    elif '화재' in values:
        test_2018['bq5_2'] = test_2018['bq5_2'].str.replace(values, '화재')
# Out:
# 100%|██████████| 9069/9069 [00:19<00:00, 458.90it/s]

# %%
for col in train_2018['bq5_2'].value_counts().loc[train_2018['bq5_2'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq5_2'] == col, 'bq5_2' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq5_2'].value_counts().index) - set(train_2018['bq5_2'].value_counts().loc[train_2018['bq5_2'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq5_2'] == col, 'bq5_2_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq28_1'] = train_2018['bq28_1'].astype(str)

train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(' ', '')
train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(')', '')
train_2018['bq28_1'] = train_2018['bq28_1'].str.replace('(', '')
train_2018['bq28_1'] = train_2018['bq28_1'].str.replace('모름', '없음')
train_2018['bq28_1'] = train_2018['bq28_1'].str.replace('없다', '없음')

# %%
for values in tqdm(train_2018['bq28_1']):
    if '1인가구' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '1인가구')
    elif '1인미디어' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '유튜브')
    elif '1인방송' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '유튜브')
    elif '3D' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '3D')
    elif '4차' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '4차산업')
    elif 'AI' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, 'AI')
    elif 'IT' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, 'IT')
    elif '건강' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '건강')
    elif '건물' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '건물')
    elif '건설' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '건설')
    elif '건축' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '건축')
    elif '게임' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '게임')
    elif '결혼' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '결혼')   
    elif '고령' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '고령')   
    elif '공무원' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '공무원')
    elif '공연' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '공연')
    elif '공장' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '공장')
    elif '공정' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '공정')
    elif '과학' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '과학')
    elif '관광' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '관광')
    elif '광고' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '광고')
    elif '광산' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '광산')
    elif '교사' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '교사')
    elif '교육' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '교육')   
    elif '교통' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '교통')   
    elif '국방' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '국방')
    elif '국악' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '국악')
    elif '군인' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '국방')
    elif '근무' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '근무')
    elif '금연' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '금연')
    elif '금융' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '금융')
    elif '기계' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '기계')
    elif '기술' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '기술')
    elif '화학' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '화학')
    elif '화장품' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '화장품')   
    elif '해외여행' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '해외여행')   # ㄴ에서 끝남
    elif '항공' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '항공')   
    elif '한복' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '한복')
    elif '학생' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '학생')
    elif '학령' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '학생')
    elif '학교' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '학교')
    elif '피부' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '피부')
    elif '평균수명' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '고령화')
    elif '패션' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '패션')
    elif '통신' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '통신')
    elif '통계' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '통계')
    elif '태양' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '태양')   
    elif '클래식' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '클래식')         
    elif '케이블' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '케이블')   
    elif '컴퓨터' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '컴퓨터')
    elif '커피' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '커피')
    elif '친환경' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '친환경')
    elif '출판' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '출판')
    elif '출생' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '출생')
    elif '출산' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '출산')
    elif '철도' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '철도')
    elif '주택' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '주택')
    elif '종편' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '종편')
    elif '종교' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '종교')   
    elif '조선' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '조선업') 
    elif '제조업' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '제조업')   
    elif '정책' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '정책')
    elif '정부' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '정책')
    elif '정보화' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '정보화')
    elif '젊은' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '젊은층')
    elif '전자상' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '전자상')
    elif '전산' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '전산화')
    elif '저출산' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '저출산')
    elif '자동화' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '자동화')
    elif '인터넷' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '인터넷')
    elif '인쇄업' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '인쇄업')   
    elif '인구' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '인구감소') 
    elif '인공지능' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, 'AI')   
    elif '의학' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '의학')
    elif '의약' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '의약')
    elif '의류' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '의류')
    elif '의료' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '의료')
    elif '음악' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '음악')
    elif '은행' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '은행')
    elif '웹사이트' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '웹사이트')
    elif '외식' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '외식')
    elif '외국인' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '외국인')
    elif '온라인' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '온라인')   
    elif '예술' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '예술') 
    elif '영화' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '영화')   
    elif '영상' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '영상')
    elif '연예인' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '연예인')
    elif '연극' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '연극')
    elif '연구' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '연구')
    elif '역사' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '역사')
    elif '여행' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '여행')
    elif '여가' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '여가')
    elif '에너지' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '에너지')
    elif '동물' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '동물')
    elif '아파트' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '아파트')   
    elif '아이들' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '저출산') 
    elif '오토바이' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '오토바이') 
    elif '식품' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '식품')   
    elif '승강기' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '승강기')
    elif '스포츠' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '스포츠')
    elif '스마트' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '스마트')
    elif '농산물' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '농산물')
    elif '섬유' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '섬유')
    elif '보험' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '보험')
    elif '병원' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '병원')
    elif '병역' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '병역')
    elif '법적' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '법적')
    elif '법원' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '법원')   
    elif '법률' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '법률') 
    elif '범죄' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '범죄') 
    elif '버스' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '버스') 
    elif '방송' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '방송')   
    elif '반도체' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '반도체')
    elif '박물관' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '박물관')
    elif '미용' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '미용')
    elif '미술' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '미술')
    elif '미디어' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '미디어')
    elif '무인' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '무인')
    elif '모바일' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '모바일')
    elif '마케팅' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '마케팅')
    elif '로봇' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '로봇')
    elif '라디오' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '라디오')   
    elif '디지털카메라' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '디지털카메라') 
    elif '디자인' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '디자인') 
    elif '디자이너' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '디자이너') 
    elif '드론' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '드론')   
    elif '농업' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '농업')
    elif '노인' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '노인')
    elif '노령화' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '고령')

    elif '대학' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '대학')
    elif '대형마트' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '대형마트')
    elif '데이터' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '데이터')
    elif '먹거리' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '먹거리')
    elif '물량' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '물량')   
    elif '사람의' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '사람') 
    elif '사람이' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '사람') 
    elif '셀프주유' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '주유') 
    elif '신약' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '신약')   
    elif '자동차' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '자동차')
    elif '전기' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '전기')
    elif '전력' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '전기')
    elif '제조' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '제조')
    elif '치아' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '치아')
    elif '택배' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '택배')
    elif '홈쇼핑' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '홈쇼핑')
    elif '환경' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '환경')   
    elif '환자' in values:
        train_2018['bq28_1'] = train_2018['bq28_1'].str.replace(values, '환자')
# Out:
# 100%|██████████| 9072/9072 [00:29<00:00, 306.04it/s]

# %%
for col in train_2018['bq28_1'].value_counts().loc[train_2018['bq28_1'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq28_1'] == col, 'bq28_1' + col] = 1
    train_2018 = train_2018.fillna(0)

for col in train_2018['bq28_1'].value_counts().loc[train_2018['bq28_1'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq28_1'] == col, 'bq28_1_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq28_1'] = test_2018['bq28_1'].astype(str)

test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(' ', '')
test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(')', '')
test_2018['bq28_1'] = test_2018['bq28_1'].str.replace('(', '')
test_2018['bq28_1'] = test_2018['bq28_1'].str.replace('모름', '없음')
test_2018['bq28_1'] = test_2018['bq28_1'].str.replace('없다', '없음')

# %%
for values in tqdm(test_2018['bq28_1']):
    if '1인가구' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '1인가구')
    elif '1인미디어' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '유튜브')
    elif '1인방송' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '유튜브')
    elif '3D' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '3D')
    elif '4차' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '4차산업')
    elif 'AI' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, 'AI')
    elif 'IT' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, 'IT')
    elif '건강' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '건강')
    elif '건물' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '건물')
    elif '건설' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '건설')
    elif '건축' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '건축')
    elif '게임' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '게임')
    elif '결혼' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '결혼')   
    elif '고령' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '고령')   
    elif '공무원' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '공무원')
    elif '공연' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '공연')
    elif '공장' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '공장')
    elif '공정' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '공정')
    elif '과학' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '과학')
    elif '관광' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '관광')
    elif '광고' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '광고')
    elif '광산' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '광산')
    elif '교사' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '교사')
    elif '교육' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '교육')   
    elif '교통' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '교통')   
    elif '국방' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '국방')
    elif '국악' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '국악')
    elif '군인' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '국방')
    elif '근무' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '근무')
    elif '금연' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '금연')
    elif '금융' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '금융')
    elif '기계' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '기계')
    elif '기술' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '기술')
    elif '화학' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '화학')
    elif '화장품' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '화장품')   
    elif '해외여행' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '해외여행')   # ㄴ에서 끝남
    elif '항공' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '항공')   
    elif '한복' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '한복')
    elif '학생' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '학생')
    elif '학령' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '학생')
    elif '학교' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '학교')
    elif '피부' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '피부')
    elif '평균수명' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '고령화')
    elif '패션' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '패션')
    elif '통신' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '통신')
    elif '통계' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '통계')
    elif '태양' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '태양')   
    elif '클래식' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '클래식')         
    elif '케이블' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '케이블')   
    elif '컴퓨터' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '컴퓨터')
    elif '커피' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '커피')
    elif '친환경' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '친환경')
    elif '출판' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '출판')
    elif '출생' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '출생')
    elif '출산' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '출산')
    elif '철도' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '철도')
    elif '주택' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '주택')
    elif '종편' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '종편')
    elif '종교' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '종교')   
    elif '조선' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '조선업') 
    elif '제조업' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '제조업')   
    elif '정책' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '정책')
    elif '정부' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '정책')
    elif '정보화' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '정보화')
    elif '젊은' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '젊은층')
    elif '전자상' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '전자상')
    elif '전산' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '전산화')
    elif '저출산' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '저출산')
    elif '자동화' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '자동화')
    elif '인터넷' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '인터넷')
    elif '인쇄업' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '인쇄업')   
    elif '인구' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '인구감소') 
    elif '인공지능' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, 'AI')   
    elif '의학' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '의학')
    elif '의약' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '의약')
    elif '의류' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '의류')
    elif '의료' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '의료')
    elif '음악' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '음악')
    elif '은행' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '은행')
    elif '웹사이트' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '웹사이트')
    elif '외식' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '외식')
    elif '외국인' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '외국인')
    elif '온라인' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '온라인')   
    elif '예술' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '예술') 
    elif '영화' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '영화')   
    elif '영상' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '영상')
    elif '연예인' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '연예인')
    elif '연극' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '연극')
    elif '연구' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '연구')
    elif '역사' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '역사')
    elif '여행' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '여행')
    elif '여가' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '여가')
    elif '에너지' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '에너지')
    elif '동물' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '동물')
    elif '아파트' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '아파트')   
    elif '아이들' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '저출산') 
    elif '오토바이' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '오토바이') 
    elif '식품' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '식품')   
    elif '승강기' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '승강기')
    elif '스포츠' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '스포츠')
    elif '스마트' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '스마트')
    elif '농산물' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '농산물')
    elif '섬유' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '섬유')
    elif '보험' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '보험')
    elif '병원' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '병원')
    elif '병역' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '병역')
    elif '법적' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '법적')
    elif '법원' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '법원')   
    elif '법률' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '법률') 
    elif '범죄' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '범죄') 
    elif '버스' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '버스') 
    elif '방송' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '방송')   
    elif '반도체' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '반도체')
    elif '박물관' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '박물관')
    elif '미용' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '미용')
    elif '미술' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '미술')
    elif '미디어' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '미디어')
    elif '무인' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '무인')
    elif '모바일' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '모바일')
    elif '마케팅' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '마케팅')
    elif '로봇' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '로봇')
    elif '라디오' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '라디오')   
    elif '디지털카메라' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '디지털카메라') 
    elif '디자인' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '디자인') 
    elif '디자이너' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '디자이너') 
    elif '드론' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '드론')   
    elif '농업' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '농업')
    elif '노인' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '노인')
    elif '노령화' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '고령')

    elif '대학' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '대학')
    elif '대형마트' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '대형마트')
    elif '데이터' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '데이터')
    elif '먹거리' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '먹거리')
    elif '물량' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '물량')   
    elif '사람의' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '사람') 
    elif '사람이' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '사람') 
    elif '셀프주유' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '주유') 
    elif '신약' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '신약')   
    elif '자동차' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '자동차')
    elif '전기' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '전기')
    elif '전력' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '전기')
    elif '제조' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '제조')
    elif '치아' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '치아')
    elif '택배' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '택배')
    elif '홈쇼핑' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '홈쇼핑')
    elif '환경' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '환경')   
    elif '환자' in values:
        test_2018['bq28_1'] = test_2018['bq28_1'].str.replace(values, '환자')
# Out:
# 100%|██████████| 9069/9069 [00:30<00:00, 299.91it/s]

# %%
for col in train_2018['bq28_1'].value_counts().loc[train_2018['bq28_1'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq28_1'] == col, 'bq28_1' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq28_1'].value_counts().index) - set(train_2018['bq28_1'].value_counts().loc[train_2018['bq28_1'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq28_1'] == col, 'bq28_1_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq4_1a'] = train_2018['bq4_1a'].astype(str)

train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(' ', '')
train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(')', '')
train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace('(', '')
train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace('모름', '없음')
train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace('없다', '없음')

train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace('가능사', '')
train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace('기사', '')

# %%
for values in tqdm(train_2018['bq4_1a']):
    if '한의사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '한의사')
    elif '의사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '의사')
    elif '정보처리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정보처리')
    elif '전기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '전기')
    elif '변호사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '변호사')
    elif '간호' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '간호사')
    elif '회계' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '회계')
    elif '환경' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '환경')
    elif '전문의' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '의사')
    elif '세무사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '세무사')
    elif '교통' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '교통')
    elif '중개' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '부동산')
    elif '사회복지' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '사회복지')   
    elif '부동산' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '부동산')   
    elif '정비' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정비')   
    elif '양식' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '양식')   
    elif '일식' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '일식')
    elif '한식' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '한식')
    elif '중식' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '중식')
    elif '변리사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '변리사')   
    elif '정비' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정비')
    elif '토목' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '토목')
    elif '약사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '약사')
    elif '아동' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '아동')
    elif '유치원' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '아동')        
    elif '정교사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정교사')
    elif '운전면허' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '운전면허')
    elif '노무사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '노무사')
    elif '초등교사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '교원자격증')
    elif '중등교' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '교원자격증')      
    elif '1종' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '1종')
    elif 'CAD' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, 'CAD')        
    elif '택시' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '택시')
    elif '건설기계' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건설기계')
    elif '경기지도사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '경기지도사')
    elif '미용' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '미용')
    elif '교원' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '교원자격증')       
    elif '공무원' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '공무원')
    elif '금융' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '금융')        
    elif '기록' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '기록')
    elif '레크레이션' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '레크레이션')
    elif '물리치료' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '물리치료')
    elif '미용' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '미용')
    elif '방사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '방사')   
    elif '보일러' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '보일러')        
    elif '비파괴' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '비파괴')
    elif '사진' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '사진')
    elif '소방설비' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '소방설비')
    elif '수질' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '수질')
    elif '승강기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '승강기')   
    elif '실내건축' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '실내건축')   
    elif '워드프로' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '워드프로')        
    elif '의료보조' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '의료보조')
    elif '전자상거래' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '전자상거래')
    elif '정보통신' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정보통신')
    elif '수질' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '수질')
    elif '승강기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '승강기')   
    elif '교사자격' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '교원')
    elif '국내여행' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '국내여행')
    elif '코디네이터' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '코디네이터')
    elif '굴삭기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '굴삭기')
    elif '귀금속' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '귀금속')   
    elif '기계설계' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '기계설계')
    elif '메이크업' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '메이크업')
    elif '바리스타' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '바리스타')
    elif '박사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '박사')
    elif '보육교사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '보육교사')   
    elif '산림경영' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '산림경영')
    elif '코디네이터' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '코디네이터')
    elif '산업안전' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '산업안전')
    elif '생활체육' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '생활체육')   
    elif '석사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '석사')
    elif '제과' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '제과')
    elif '조경' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '조경')
    elif '제빵' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '제빵')
    elif '지게차' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '지게차')       
    elif '청소년' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '청소년')
    elif '치과' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '치과')
    elif '컨벤션' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '컨벤션')        
    elif '컴퓨터그래픽' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '컴퓨터그래픽')       
    elif '태권도' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '태권도')
    elif '해기사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '해기사')
    elif '화물운송' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '화물운송') 
    elif '화학분석' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '화학분석')         
    elif '가스' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '가스')        
    elif '가이드' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '가이드')       
    elif '건설재료' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건설재료')
    elif '공조냉동' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '공조냉동')
    elif '관광통역' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '관광통역') 
    elif '기계설비' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '기계설비')    
    elif '놀이' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '놀이')       
    elif '바둑' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '바둑')
    elif '방송통신' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '방송통신')
    elif '베이비' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '베이비') 
    elif '보험' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '보험') 
    elif '소음진동' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '소음진동')
    elif '식품' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '식품')
    elif '언어재활' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '언어재활') 
    elif '영양사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '영양사') 
    elif '용접' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '용접') 
    elif '웹디자인' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '웹디자인') 
    elif '위험물' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '위험물') 
    elif '응급구조' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '응급구조') 
    elif '임상병리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '임상병리') 
    elif '임상심리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '임상심리') 

    elif '건설기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건설기') 
    elif '건축감리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건축감리') 
    elif '건축목' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건축목') 
    elif '경비' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '경비') 
    elif 'KOLAS' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, 'KOLAS') 
    elif '관세사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '관세사') 
    elif '국외여행인솔자' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '국외여행인솔자') 
    elif '기계관련' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '기계관련')        
    elif '네일아트' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '네일아트') 
    elif '드론' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '드론') 
    elif '마술' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '마술') 
    elif '무대예술' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '무대예술') 
    elif '무선설비' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '무선설비') 
    elif '문화재수리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '문화재수리') 
    elif '미술' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '미술') 
    elif '박물관' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '박물관')      
    elif '배관' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '배관') 
    elif '비서' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '비서') 
    elif '산림' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '산림') 
    elif '생활스포츠' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '생활스포츠') 
    elif '설계' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '설계') 
    elif '세탁' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '세탁') 
    elif '소방' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '소방') 
    elif '심리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '심리')       
    elif '에너지' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '에너지') 
    elif '열관리기능' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '열관리기능') 
    elif '캐드' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, 'CAD') 
    elif '요양' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '요양') 
    elif '운송용' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '운송용') 
    elif '인명' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '인명') 
    elif '자동차' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '자동차') 
    elif '전산응용' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '전산응용')   
    elif '정보보안' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정보보안') 
    elif '정보시스템' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정보시스템') 
    elif '정수' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정수') 
    elif '조주' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '조주') 
    elif '직업상담' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '직업상담') 
    elif '초경량' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '초경량') 
    elif '측량' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '측량') 
    elif '컴퓨터' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '컴퓨터') 
        
    elif '투자' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '투자')   
    elif '품질' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '품질') 
    elif '한글' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '한글') 
    elif '항해' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '항해') 
    elif '화약' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '화약') 
    elif '화훼' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '화훼') 
    elif '패턴' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '패턴') 
    elif '한의' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '한의') 
    elif '한약' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '한약') 
    elif '피부관리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '피부관리')         
    elif '정교' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정교사') 
    elif '건축기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건축기') 
    elif '국내심판' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '국내심판') 
    elif '국내A' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '국내심판') 
    elif '문화예술' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '문화예술') 
    elif '방과후' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '방과후') 
    elif '보석' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '보석') 
    elif '보육교' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '보육교') 
    elif '옥외광고' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '옥외광고') 
    elif '외환' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '외환') 
    elif '워드' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '워드') 
    elif '원동기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '원동기') 
    elif '유통관리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '유통관리') 
    elif '일본어' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '일본어') 
        
    elif '전산세무' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '전산세무') 
    elif '전자기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '전자기') 
    elif '철도차량' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '철도차량') 
    elif '교감' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '교감') 
    elif '교장' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '교장') 
    elif '폐기물' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '폐기물') 
    elif '한의' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '한의사') 
    elif '회복지' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '사회복지') 
    elif '항공종' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '항공종') 
    elif '특수분장' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '특수분장') 
    elif '특수학교' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '특수학교') 
    elif '특수교' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '특수학교') 
    elif '피부' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '피부') 

    elif 'GTQ' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, 'GTQ') 
    elif 'SQL' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, 'SQL') 
    elif '건설' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건설') 
    elif '건축구조' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건축구조') 
    elif '건축도장' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건축도장') 
    elif '건축설비' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '건축설비') 
    elif '게임프로그래밍' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '게임프로그래밍') 
    elif '경기지도' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '경기지도') 
    elif '경매사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '경매사') 
    elif '경영지도' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '경영지도') 
    elif '경찰' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '경찰') 
    elif '관제' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '관제') 
    elif '광고' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '광고') 
    elif '광산' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '광산') 
    elif '국제무역' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '국제무역') 
    elif '그래픽' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '그래픽') 
    elif '금속공' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '금속공') 
    elif '금속재료' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '금속재료') 
    elif '도시계획' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '도시계획') 
    elif '반도체' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '반도체') 
    elif '보건교사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '보건교사') 
    elif '보건의료' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '보건의료') 
    elif '복지' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '사회복지')        
    elif '빅데이터' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '빅데이터') 
    elif '사서' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '사서') 
    elif '소잉디자이너' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '소잉디자이너') 
    elif '소프트웨어' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '소프트웨어') 
    elif '스포츠' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '스포츠') 
    elif '시각디자' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '시각디자인') 
    elif '신용' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '신용') 
    elif '실내디자인' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '실내디자인') 
    elif '심판' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '심판') 
    elif '악기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '악기') 
    elif '안경' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '안경')                
    elif '안마' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '안마') 
    elif '언어' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '언어') 
    elif '워드' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '워드') 
    elif '전자계산' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '전자계산') 
    elif '정사서' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '정사서') 
    elif '조리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '조리') 
    elif '지적' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '지적') 
    elif '통신선로' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '통신선로') 
    elif '판금' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '판금') 
    elif '펀드' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '펀드')
    elif '펄프' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '펄프') 
    elif '피아노조율' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '피아노조율') 
    elif '한국사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '한국사') 
    elif '금형' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '금형') 
    elif '냉동' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '냉동') 
    elif '네트워크관' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '네트워크관')
    elif '대형면허' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '대형면허') 
    elif '메이' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '메이') 
    elif '무술유단자' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '무술유단자') 
    elif '섬유' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '섬유') 
    elif '속기사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '속기사') 
    elif '열관리' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '열관리')
    elif '유리시공' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '유리시공') 
    elif '유아' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '유아') 
    elif '의지보조기' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '의지보조기') 
    elif '작업치료사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '작업치료사') 
    elif '지도자' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '지도자') 
    elif '치기공사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '치기공사')
    elif '토익' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '토익') 
    elif '학사' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '학사') 
    elif '한지' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '한지') 
    elif '조종사자격증' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '조종사자격증') 
    elif '호텔' in values:
        train_2018['bq4_1a'] = train_2018['bq4_1a'].str.replace(values, '호텔')
# Out:
# 100%|██████████| 9072/9072 [00:17<00:00, 506.18it/s]

# %%
for col in train_2018['bq4_1a'].value_counts().loc[train_2018['bq4_1a'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq4_1a'] == col, 'bq4_1a' + col] = 1
    train_2018 = train_2018.fillna(0)

for col in train_2018['bq4_1a'].value_counts().loc[train_2018['bq4_1a'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq4_1a'] == col, 'bq4_1a_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq4_1a'] = test_2018['bq4_1a'].astype(str)

test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(' ', '')
test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(')', '')
test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace('(', '')
test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace('모름', '없음')
test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace('없다', '없음')

test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace('가능사', '')
test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace('기사', '')

# %%
for values in tqdm(test_2018['bq4_1a']):
    if '한의사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '한의사')
    elif '의사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '의사')
    elif '정보처리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정보처리')
    elif '전기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '전기')
    elif '변호사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '변호사')
    elif '간호' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '간호사')
    elif '회계' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '회계')
    elif '환경' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '환경')
    elif '전문의' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '의사')
    elif '세무사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '세무사')
    elif '교통' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '교통')
    elif '중개' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '부동산')
    elif '사회복지' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '사회복지')   
    elif '부동산' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '부동산')   
    elif '정비' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정비')   
    elif '양식' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '양식')   
    elif '일식' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '일식')
    elif '한식' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '한식')
    elif '중식' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '중식')
    elif '변리사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '변리사')   
    elif '정비' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정비')
    elif '토목' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '토목')
    elif '약사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '약사')
    elif '아동' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '아동')
    elif '유치원' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '아동')        
    elif '정교사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정교사')
    elif '운전면허' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '운전면허')
    elif '노무사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '노무사')
    elif '초등교사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '교원자격증')
    elif '중등교' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '교원자격증')      
    elif '1종' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '1종')
    elif 'CAD' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, 'CAD')        
    elif '택시' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '택시')
    elif '건설기계' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건설기계')
    elif '경기지도사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '경기지도사')
    elif '미용' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '미용')
    elif '교원' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '교원자격증')       
    elif '공무원' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '공무원')
    elif '금융' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '금융')        
    elif '기록' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '기록')
    elif '레크레이션' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '레크레이션')
    elif '물리치료' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '물리치료')
    elif '미용' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '미용')
    elif '방사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '방사')   
    elif '보일러' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '보일러')        
    elif '비파괴' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '비파괴')
    elif '사진' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '사진')
    elif '소방설비' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '소방설비')
    elif '수질' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '수질')
    elif '승강기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '승강기')   
    elif '실내건축' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '실내건축')   
    elif '워드프로' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '워드프로')        
    elif '의료보조' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '의료보조')
    elif '전자상거래' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '전자상거래')
    elif '정보통신' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정보통신')
    elif '수질' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '수질')
    elif '승강기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '승강기')   
    elif '교사자격' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '교원')
    elif '국내여행' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '국내여행')
    elif '코디네이터' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '코디네이터')
    elif '굴삭기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '굴삭기')
    elif '귀금속' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '귀금속')   
    elif '기계설계' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '기계설계')
    elif '메이크업' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '메이크업')
    elif '바리스타' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '바리스타')
    elif '박사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '박사')
    elif '보육교사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '보육교사')   
    elif '산림경영' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '산림경영')
    elif '코디네이터' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '코디네이터')
    elif '산업안전' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '산업안전')
    elif '생활체육' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '생활체육')   
    elif '석사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '석사')
    elif '제과' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '제과')
    elif '조경' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '조경')
    elif '제빵' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '제빵')
    elif '지게차' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '지게차')       
    elif '청소년' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '청소년')
    elif '치과' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '치과')
    elif '컨벤션' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '컨벤션')        
    elif '컴퓨터그래픽' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '컴퓨터그래픽')       
    elif '태권도' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '태권도')
    elif '해기사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '해기사')
    elif '화물운송' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '화물운송') 
    elif '화학분석' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '화학분석')         
    elif '가스' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '가스')        
    elif '가이드' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '가이드')       
    elif '건설재료' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건설재료')
    elif '공조냉동' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '공조냉동')
    elif '관광통역' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '관광통역') 
    elif '기계설비' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '기계설비')    
    elif '놀이' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '놀이')       
    elif '바둑' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '바둑')
    elif '방송통신' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '방송통신')
    elif '베이비' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '베이비') 
    elif '보험' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '보험') 
    elif '소음진동' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '소음진동')
    elif '식품' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '식품')
    elif '언어재활' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '언어재활') 
    elif '영양사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '영양사') 
    elif '용접' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '용접') 
    elif '웹디자인' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '웹디자인') 
    elif '위험물' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '위험물') 
    elif '응급구조' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '응급구조') 
    elif '임상병리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '임상병리') 
    elif '임상심리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '임상심리') 

    elif '건설기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건설기') 
    elif '건축감리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건축감리') 
    elif '건축목' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건축목') 
    elif '경비' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '경비') 
    elif 'KOLAS' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, 'KOLAS') 
    elif '관세사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '관세사') 
    elif '국외여행인솔자' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '국외여행인솔자') 
    elif '기계관련' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '기계관련')        
    elif '네일아트' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '네일아트') 
    elif '드론' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '드론') 
    elif '마술' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '마술') 
    elif '무대예술' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '무대예술') 
    elif '무선설비' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '무선설비') 
    elif '문화재수리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '문화재수리') 
    elif '미술' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '미술') 
    elif '박물관' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '박물관')      
    elif '배관' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '배관') 
    elif '비서' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '비서') 
    elif '산림' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '산림') 
    elif '생활스포츠' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '생활스포츠') 
    elif '설계' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '설계') 
    elif '세탁' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '세탁') 
    elif '소방' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '소방') 
    elif '심리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '심리')       
    elif '에너지' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '에너지') 
    elif '열관리기능' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '열관리기능') 
    elif '캐드' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, 'CAD') 
    elif '요양' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '요양') 
    elif '운송용' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '운송용') 
    elif '인명' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '인명') 
    elif '자동차' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '자동차') 
    elif '전산응용' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '전산응용')   
    elif '정보보안' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정보보안') 
    elif '정보시스템' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정보시스템') 
    elif '정수' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정수') 
    elif '조주' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '조주') 
    elif '직업상담' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '직업상담') 
    elif '초경량' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '초경량') 
    elif '측량' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '측량') 
    elif '컴퓨터' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '컴퓨터') 
        
    elif '투자' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '투자')   
    elif '품질' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '품질') 
    elif '한글' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '한글') 
    elif '항해' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '항해') 
    elif '화약' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '화약') 
    elif '화훼' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '화훼') 
    elif '패턴' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '패턴') 
    elif '한의' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '한의') 
    elif '한약' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '한약') 
    elif '피부관리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '피부관리')         
    elif '정교' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정교사') 
    elif '건축기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건축기') 
    elif '국내심판' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '국내심판') 
    elif '국내A' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '국내심판') 
    elif '문화예술' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '문화예술') 
    elif '방과후' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '방과후') 
    elif '보석' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '보석') 
    elif '보육교' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '보육교') 
    elif '옥외광고' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '옥외광고') 
    elif '외환' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '외환') 
    elif '워드' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '워드') 
    elif '원동기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '원동기') 
    elif '유통관리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '유통관리') 
    elif '일본어' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '일본어') 
        
    elif '전산세무' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '전산세무') 
    elif '전자기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '전자기') 
    elif '철도차량' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '철도차량') 
    elif '교감' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '교감') 
    elif '교장' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '교장') 
    elif '폐기물' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '폐기물') 
    elif '한의' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '한의사') 
    elif '회복지' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '사회복지') 
    elif '항공종' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '항공종') 
    elif '특수분장' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '특수분장') 
    elif '특수학교' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '특수학교') 
    elif '특수교' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '특수학교') 
    elif '피부' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '피부') 

    elif 'GTQ' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, 'GTQ') 
    elif 'SQL' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, 'SQL') 
    elif '건설' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건설') 
    elif '건축구조' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건축구조') 
    elif '건축도장' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건축도장') 
    elif '건축설비' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '건축설비') 
    elif '게임프로그래밍' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '게임프로그래밍') 
    elif '경기지도' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '경기지도') 
    elif '경매사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '경매사') 
    elif '경영지도' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '경영지도') 
    elif '경찰' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '경찰') 
    elif '관제' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '관제') 
    elif '광고' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '광고') 
    elif '광산' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '광산') 
    elif '국제무역' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '국제무역') 
    elif '그래픽' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '그래픽') 
    elif '금속공' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '금속공') 
    elif '금속재료' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '금속재료') 
    elif '도시계획' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '도시계획') 
    elif '반도체' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '반도체') 
    elif '보건교사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '보건교사') 
    elif '보건의료' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '보건의료') 
    elif '복지' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '사회복지')        
    elif '빅데이터' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '빅데이터') 
    elif '사서' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '사서') 
    elif '소잉디자이너' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '소잉디자이너') 
    elif '소프트웨어' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '소프트웨어') 
    elif '스포츠' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '스포츠') 
    elif '시각디자' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '시각디자인') 
    elif '신용' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '신용') 
    elif '실내디자인' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '실내디자인') 
    elif '심판' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '심판') 
    elif '악기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '악기') 
    elif '안경' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '안경')                
    elif '안마' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '안마') 
    elif '언어' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '언어') 
    elif '워드' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '워드') 
    elif '전자계산' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '전자계산') 
    elif '정사서' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '정사서') 
    elif '조리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '조리') 
    elif '지적' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '지적') 
    elif '통신선로' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '통신선로') 
    elif '판금' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '판금') 
    elif '펀드' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '펀드')
    elif '펄프' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '펄프') 
    elif '피아노조율' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '피아노조율') 
    elif '한국사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '한국사') 
    elif '금형' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '금형') 
    elif '냉동' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '냉동') 
    elif '네트워크관' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '네트워크관')
    elif '대형면허' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '대형면허') 
    elif '메이' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '메이') 
    elif '무술유단자' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '무술유단자') 
    elif '섬유' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '섬유') 
    elif '속기사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '속기사') 
    elif '열관리' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '열관리')
    elif '유리시공' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '유리시공') 
    elif '유아' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '유아') 
    elif '의지보조기' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '의지보조기') 
    elif '작업치료사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '작업치료사') 
    elif '지도자' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '지도자') 
    elif '치기공사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '치기공사')
    elif '토익' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '토익') 
    elif '학사' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '학사') 
    elif '한지' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '한지') 
    elif '조종사자격증' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '조종사자격증') 
    elif '호텔' in values:
        test_2018['bq4_1a'] = test_2018['bq4_1a'].str.replace(values, '호텔')
# Out:
# 100%|██████████| 9069/9069 [00:18<00:00, 499.05it/s]

# %%
for col in train_2018['bq4_1a'].value_counts().loc[train_2018['bq4_1a'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq4_1a'] == col, 'bq4_1a' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq4_1a'].value_counts().index) - set(train_2018['bq4_1a'].value_counts().loc[train_2018['bq4_1a'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq4_1a'] == col, 'bq4_1a_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq4_1b'] = train_2018['bq4_1b'].astype(str)

train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(' ', '')
train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(')', '')
train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace('(', '')
train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace('모름', '없음')
train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace('없다', '없음')

train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace('가능사', '')
train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace('기사', '')

# %%
for values in tqdm(train_2018['bq4_1b']):
    if '한의사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '한의사')
    elif '의사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '의사')
    elif '정보처리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정보처리')
    elif '전기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '전기')
    elif '변호사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '변호사')
    elif '간호' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '간호사')
    elif '회계' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '회계')
    elif '환경' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '환경')
    elif '전문의' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '의사')
    elif '세무사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '세무사')
    elif '교통' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '교통')
    elif '중개' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '부동산')
    elif '사회복지' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '사회복지')   
    elif '부동산' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '부동산')   
    elif '정비' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정비')   
    elif '양식' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '양식')   
    elif '일식' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '일식')
    elif '한식' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '한식')
    elif '중식' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '중식')
    elif '변리사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '변리사')   
    elif '정비' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정비')
    elif '토목' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '토목')
    elif '약사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '약사')
    elif '아동' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '아동')
    elif '유치원' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '아동')        
    elif '정교사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정교사')
    elif '운전면허' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '운전면허')
    elif '노무사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '노무사')
    elif '초등교사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '교원자격증')
    elif '중등교' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '교원자격증')      
    elif '1종' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '1종')
    elif 'CAD' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, 'CAD')        
    elif '택시' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '택시')
    elif '건설기계' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건설기계')
    elif '경기지도사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '경기지도사')
    elif '미용' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '미용')
    elif '교원' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '교원자격증')       
    elif '공무원' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '공무원')
    elif '금융' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '금융')        
    elif '기록' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '기록')
    elif '레크레이션' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '레크레이션')
    elif '물리치료' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '물리치료')
    elif '미용' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '미용')
    elif '방사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '방사')   
    elif '보일러' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '보일러')        
    elif '비파괴' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '비파괴')
    elif '사진' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '사진')
    elif '소방설비' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '소방설비')
    elif '수질' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '수질')
    elif '승강기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '승강기')   
    elif '실내건축' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '실내건축')   
    elif '워드프로' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '워드프로')        
    elif '의료보조' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '의료보조')
    elif '전자상거래' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '전자상거래')
    elif '정보통신' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정보통신')
    elif '수질' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '수질')
    elif '승강기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '승강기')   
    elif '교사자격' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '교원')
    elif '국내여행' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '국내여행')
    elif '코디네이터' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '코디네이터')
    elif '굴삭기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '굴삭기')
    elif '귀금속' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '귀금속')   
    elif '기계설계' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '기계설계')
    elif '메이크업' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '메이크업')
    elif '바리스타' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '바리스타')
    elif '박사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '박사')
    elif '보육교사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '보육교사')   
    elif '산림경영' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '산림경영')
    elif '코디네이터' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '코디네이터')
    elif '산업안전' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '산업안전')
    elif '생활체육' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '생활체육')   
    elif '석사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '석사')
    elif '제과' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '제과')
    elif '조경' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '조경')
    elif '제빵' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '제빵')
    elif '지게차' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '지게차')       
    elif '청소년' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '청소년')
    elif '치과' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '치과')
    elif '컨벤션' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '컨벤션')        
    elif '컴퓨터그래픽' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '컴퓨터그래픽')       
    elif '태권도' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '태권도')
    elif '해기사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '해기사')
    elif '화물운송' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '화물운송') 
    elif '화학분석' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '화학분석')         
    elif '가스' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '가스')        
    elif '가이드' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '가이드')       
    elif '건설재료' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건설재료')
    elif '공조냉동' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '공조냉동')
    elif '관광통역' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '관광통역') 
    elif '기계설비' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '기계설비')    
    elif '놀이' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '놀이')       
    elif '바둑' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '바둑')
    elif '방송통신' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '방송통신')
    elif '베이비' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '베이비') 
    elif '보험' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '보험') 
    elif '소음진동' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '소음진동')
    elif '식품' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '식품')
    elif '언어재활' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '언어재활') 
    elif '영양사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '영양사') 
    elif '용접' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '용접') 
    elif '웹디자인' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '웹디자인') 
    elif '위험물' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '위험물') 
    elif '응급구조' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '응급구조') 
    elif '임상병리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '임상병리') 
    elif '임상심리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '임상심리') 

    elif '건설기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건설기') 
    elif '건축감리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건축감리') 
    elif '건축목' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건축목') 
    elif '경비' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '경비') 
    elif 'KOLAS' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, 'KOLAS') 
    elif '관세사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '관세사') 
    elif '국외여행인솔자' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '국외여행인솔자') 
    elif '기계관련' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '기계관련')        
    elif '네일아트' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '네일아트') 
    elif '드론' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '드론') 
    elif '마술' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '마술') 
    elif '무대예술' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '무대예술') 
    elif '무선설비' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '무선설비') 
    elif '문화재수리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '문화재수리') 
    elif '미술' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '미술') 
    elif '박물관' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '박물관')      
    elif '배관' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '배관') 
    elif '비서' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '비서') 
    elif '산림' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '산림') 
    elif '생활스포츠' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '생활스포츠') 
    elif '설계' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '설계') 
    elif '세탁' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '세탁') 
    elif '소방' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '소방') 
    elif '심리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '심리')       
    elif '에너지' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '에너지') 
    elif '열관리기능' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '열관리기능') 
    elif '캐드' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, 'CAD') 
    elif '요양' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '요양') 
    elif '운송용' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '운송용') 
    elif '인명' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '인명') 
    elif '자동차' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '자동차') 
    elif '전산응용' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '전산응용')   
    elif '정보보안' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정보보안') 
    elif '정보시스템' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정보시스템') 
    elif '정수' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정수') 
    elif '조주' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '조주') 
    elif '직업상담' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '직업상담') 
    elif '초경량' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '초경량') 
    elif '측량' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '측량') 
    elif '컴퓨터' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '컴퓨터') 
        
    elif '투자' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '투자')   
    elif '품질' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '품질') 
    elif '한글' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '한글') 
    elif '항해' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '항해') 
    elif '화약' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '화약') 
    elif '화훼' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '화훼') 
    elif '패턴' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '패턴') 
    elif '한의' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '한의') 
    elif '한약' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '한약') 
    elif '피부관리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '피부관리')         
    elif '정교' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정교사') 
    elif '건축기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건축기') 
    elif '국내심판' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '국내심판') 
    elif '국내A' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '국내심판') 
    elif '문화예술' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '문화예술') 
    elif '방과후' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '방과후') 
    elif '보석' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '보석') 
    elif '보육교' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '보육교') 
    elif '옥외광고' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '옥외광고') 
    elif '외환' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '외환') 
    elif '워드' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '워드') 
    elif '원동기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '원동기') 
    elif '유통관리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '유통관리') 
    elif '일본어' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '일본어') 
        
    elif '전산세무' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '전산세무') 
    elif '전자기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '전자기') 
    elif '철도차량' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '철도차량') 
    elif '교감' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '교감') 
    elif '교장' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '교장') 
    elif '폐기물' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '폐기물') 
    elif '한의' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '한의사') 
    elif '회복지' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '사회복지') 
    elif '항공종' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '항공종') 
    elif '특수분장' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '특수분장') 
    elif '특수학교' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '특수학교') 
    elif '특수교' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '특수학교') 
    elif '피부' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '피부') 

    elif 'GTQ' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, 'GTQ') 
    elif 'SQL' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, 'SQL') 
    elif '건설' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건설') 
    elif '건축구조' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건축구조') 
    elif '건축도장' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건축도장') 
    elif '건축설비' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '건축설비') 
    elif '게임프로그래밍' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '게임프로그래밍') 
    elif '경기지도' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '경기지도') 
    elif '경매사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '경매사') 
    elif '경영지도' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '경영지도') 
    elif '경찰' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '경찰') 
    elif '관제' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '관제') 
    elif '광고' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '광고') 
    elif '광산' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '광산') 
    elif '국제무역' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '국제무역') 
    elif '그래픽' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '그래픽') 
    elif '금속공' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '금속공') 
    elif '금속재료' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '금속재료') 
    elif '도시계획' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '도시계획') 
    elif '반도체' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '반도체') 
    elif '보건교사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '보건교사') 
    elif '보건의료' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '보건의료') 
    elif '복지' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '사회복지')        
    elif '빅데이터' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '빅데이터') 
    elif '사서' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '사서') 
    elif '소잉디자이너' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '소잉디자이너') 
    elif '소프트웨어' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '소프트웨어') 
    elif '스포츠' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '스포츠') 
    elif '시각디자' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '시각디자인') 
    elif '신용' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '신용') 
    elif '실내디자인' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '실내디자인') 
    elif '심판' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '심판') 
    elif '악기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '악기') 
    elif '안경' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '안경')                
    elif '안마' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '안마') 
    elif '언어' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '언어') 
    elif '워드' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '워드') 
    elif '전자계산' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '전자계산') 
    elif '정사서' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '정사서') 
    elif '조리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '조리') 
    elif '지적' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '지적') 
    elif '통신선로' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '통신선로') 
    elif '판금' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '판금') 
    elif '펀드' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '펀드')
    elif '펄프' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '펄프') 
    elif '피아노조율' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '피아노조율') 
    elif '한국사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '한국사') 
    elif '금형' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '금형') 
    elif '냉동' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '냉동') 
    elif '네트워크관' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '네트워크관')
    elif '대형면허' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '대형면허') 
    elif '메이' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '메이') 
    elif '무술유단자' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '무술유단자') 
    elif '섬유' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '섬유') 
    elif '속기사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '속기사') 
    elif '열관리' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '열관리')
    elif '유리시공' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '유리시공') 
    elif '유아' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '유아') 
    elif '의지보조기' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '의지보조기') 
    elif '작업치료사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '작업치료사') 
    elif '지도자' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '지도자') 
    elif '치기공사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '치기공사')
    elif '토익' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '토익') 
    elif '학사' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '학사') 
    elif '한지' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '한지') 
    elif '조종사자격증' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '조종사자격증') 
    elif '호텔' in values:
        train_2018['bq4_1b'] = train_2018['bq4_1b'].str.replace(values, '호텔')
# Out:
# 100%|██████████| 9072/9072 [00:05<00:00, 1594.07it/s]

# %%
for col in train_2018['bq4_1b'].value_counts().loc[train_2018['bq4_1b'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq4_1b'] == col, 'bq4_1b' + col] = 1
    train_2018 = train_2018.fillna(0)

for col in train_2018['bq4_1b'].value_counts().loc[train_2018['bq4_1b'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq4_1b'] == col, 'bq4_1b_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq4_1b'] = test_2018['bq4_1b'].astype(str)

test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(' ', '')
test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(')', '')
test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace('(', '')
test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace('모름', '없음')
test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace('없다', '없음')

# test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace('증', '')
# test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace('사', '')
test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace('가능사', '')
test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace('기사', '')

# %%
for values in tqdm(test_2018['bq4_1b']):
    if '한의사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '한의사')
    elif '의사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '의사')
    elif '정보처리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정보처리')
    elif '전기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '전기')
    elif '변호사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '변호사')
    elif '간호' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '간호사')
    elif '회계' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '회계')
    elif '환경' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '환경')
    elif '전문의' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '의사')
    elif '세무사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '세무사')
    elif '교통' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '교통')
    elif '중개' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '부동산')
    elif '사회복지' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '사회복지')   
    elif '부동산' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '부동산')   
    elif '정비' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정비')   
    elif '양식' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '양식')   
    elif '일식' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '일식')
    elif '한식' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '한식')
    elif '중식' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '중식')
    elif '변리사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '변리사')   
    elif '정비' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정비')
    elif '토목' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '토목')
    elif '약사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '약사')
    elif '아동' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '아동')
    elif '유치원' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '아동')        
    elif '정교사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정교사')
    elif '운전면허' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '운전면허')
    elif '노무사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '노무사')
    elif '초등교사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '교원자격증')
    elif '중등교' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '교원자격증')      
    elif '1종' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '1종')
    elif 'CAD' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, 'CAD')        
    elif '택시' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '택시')
    elif '건설기계' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건설기계')
    elif '경기지도사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '경기지도사')
    elif '미용' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '미용')
    elif '교원' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '교원자격증')       
    elif '공무원' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '공무원')
    elif '금융' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '금융')        
    elif '기록' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '기록')
    elif '레크레이션' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '레크레이션')
    elif '물리치료' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '물리치료')
    elif '미용' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '미용')
    elif '방사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '방사')   
    elif '보일러' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '보일러')        
    elif '비파괴' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '비파괴')
    elif '사진' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '사진')
    elif '소방설비' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '소방설비')
    elif '수질' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '수질')
    elif '승강기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '승강기')   
    elif '실내건축' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '실내건축')   
    elif '워드프로' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '워드프로')        
    elif '의료보조' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '의료보조')
    elif '전자상거래' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '전자상거래')
    elif '정보통신' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정보통신')
    elif '수질' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '수질')
    elif '승강기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '승강기')   
    elif '교사자격' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '교원')
    elif '국내여행' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '국내여행')
    elif '코디네이터' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '코디네이터')
    elif '굴삭기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '굴삭기')
    elif '귀금속' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '귀금속')   
    elif '기계설계' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '기계설계')
    elif '메이크업' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '메이크업')
    elif '바리스타' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '바리스타')
    elif '박사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '박사')
    elif '보육교사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '보육교사')   
    elif '산림경영' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '산림경영')
    elif '코디네이터' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '코디네이터')
    elif '산업안전' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '산업안전')
    elif '생활체육' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '생활체육')   
    elif '석사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '석사')
    elif '제과' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '제과')
    elif '조경' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '조경')
    elif '제빵' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '제빵')
    elif '지게차' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '지게차')       
    elif '청소년' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '청소년')
    elif '치과' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '치과')
    elif '컨벤션' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '컨벤션')        
    elif '컴퓨터그래픽' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '컴퓨터그래픽')       
    elif '태권도' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '태권도')
    elif '해기사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '해기사')
    elif '화물운송' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '화물운송') 
    elif '화학분석' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '화학분석')         
    elif '가스' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '가스')        
    elif '가이드' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '가이드')       
    elif '건설재료' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건설재료')
    elif '공조냉동' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '공조냉동')
    elif '관광통역' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '관광통역') 
    elif '기계설비' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '기계설비')    
    elif '놀이' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '놀이')       
    elif '바둑' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '바둑')
    elif '방송통신' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '방송통신')
    elif '베이비' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '베이비') 
    elif '보험' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '보험') 
    elif '소음진동' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '소음진동')
    elif '식품' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '식품')
    elif '언어재활' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '언어재활') 
    elif '영양사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '영양사') 
    elif '용접' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '용접') 
    elif '웹디자인' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '웹디자인') 
    elif '위험물' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '위험물') 
    elif '응급구조' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '응급구조') 
    elif '임상병리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '임상병리') 
    elif '임상심리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '임상심리') 

    elif '건설기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건설기') 
    elif '건축감리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건축감리') 
    elif '건축목' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건축목') 
    elif '경비' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '경비') 
    elif 'KOLAS' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, 'KOLAS') 
    elif '관세사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '관세사') 
    elif '국외여행인솔자' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '국외여행인솔자') 
    elif '기계관련' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '기계관련')        
    elif '네일아트' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '네일아트') 
    elif '드론' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '드론') 
    elif '마술' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '마술') 
    elif '무대예술' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '무대예술') 
    elif '무선설비' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '무선설비') 
    elif '문화재수리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '문화재수리') 
    elif '미술' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '미술') 
    elif '박물관' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '박물관')      
    elif '배관' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '배관') 
    elif '비서' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '비서') 
    elif '산림' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '산림') 
    elif '생활스포츠' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '생활스포츠') 
    elif '설계' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '설계') 
    elif '세탁' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '세탁') 
    elif '소방' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '소방') 
    elif '심리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '심리')       
    elif '에너지' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '에너지') 
    elif '열관리기능' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '열관리기능') 
    elif '캐드' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, 'CAD') 
    elif '요양' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '요양') 
    elif '운송용' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '운송용') 
    elif '인명' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '인명') 
    elif '자동차' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '자동차') 
    elif '전산응용' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '전산응용')   
    elif '정보보안' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정보보안') 
    elif '정보시스템' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정보시스템') 
    elif '정수' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정수') 
    elif '조주' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '조주') 
    elif '직업상담' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '직업상담') 
    elif '초경량' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '초경량') 
    elif '측량' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '측량') 
    elif '컴퓨터' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '컴퓨터') 
        
    elif '투자' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '투자')   
    elif '품질' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '품질') 
    elif '한글' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '한글') 
    elif '항해' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '항해') 
    elif '화약' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '화약') 
    elif '화훼' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '화훼') 
    elif '패턴' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '패턴') 
    elif '한의' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '한의') 
    elif '한약' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '한약') 
    elif '피부관리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '피부관리')         
    elif '정교' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정교사') 
    elif '건축기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건축기') 
    elif '국내심판' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '국내심판') 
    elif '국내A' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '국내심판') 
    elif '문화예술' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '문화예술') 
    elif '방과후' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '방과후') 
    elif '보석' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '보석') 
    elif '보육교' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '보육교') 
    elif '옥외광고' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '옥외광고') 
    elif '외환' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '외환') 
    elif '워드' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '워드') 
    elif '원동기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '원동기') 
    elif '유통관리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '유통관리') 
    elif '일본어' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '일본어') 
        
    elif '전산세무' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '전산세무') 
    elif '전자기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '전자기') 
    elif '철도차량' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '철도차량') 
    elif '교감' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '교감') 
    elif '교장' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '교장') 
    elif '폐기물' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '폐기물') 
    elif '한의' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '한의사') 
    elif '회복지' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '사회복지') 
    elif '항공종' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '항공종') 
    elif '특수분장' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '특수분장') 
    elif '특수학교' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '특수학교') 
    elif '특수교' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '특수학교') 
    elif '피부' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '피부') 

    elif 'GTQ' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, 'GTQ') 
    elif 'SQL' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, 'SQL') 
    elif '건설' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건설') 
    elif '건축구조' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건축구조') 
    elif '건축도장' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건축도장') 
    elif '건축설비' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '건축설비') 
    elif '게임프로그래밍' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '게임프로그래밍') 
    elif '경기지도' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '경기지도') 
    elif '경매사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '경매사') 
    elif '경영지도' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '경영지도') 
    elif '경찰' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '경찰') 
    elif '관제' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '관제') 
    elif '광고' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '광고') 
    elif '광산' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '광산') 
    elif '국제무역' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '국제무역') 
    elif '그래픽' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '그래픽') 
    elif '금속공' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '금속공') 
    elif '금속재료' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '금속재료') 
    elif '도시계획' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '도시계획') 
    elif '반도체' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '반도체') 
    elif '보건교사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '보건교사') 
    elif '보건의료' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '보건의료') 
    elif '복지' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '사회복지')        
    elif '빅데이터' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '빅데이터') 
    elif '사서' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '사서') 
    elif '소잉디자이너' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '소잉디자이너') 
    elif '소프트웨어' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '소프트웨어') 
    elif '스포츠' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '스포츠') 
    elif '시각디자' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '시각디자인') 
    elif '신용' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '신용') 
    elif '실내디자인' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '실내디자인') 
    elif '심판' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '심판') 
    elif '악기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '악기') 
    elif '안경' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '안경')                
    elif '안마' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '안마') 
    elif '언어' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '언어') 
    elif '워드' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '워드') 
    elif '전자계산' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '전자계산') 
    elif '정사서' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '정사서') 
    elif '조리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '조리') 
    elif '지적' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '지적') 
    elif '통신선로' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '통신선로') 
    elif '판금' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '판금') 
    elif '펀드' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '펀드')
    elif '펄프' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '펄프') 
    elif '피아노조율' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '피아노조율') 
    elif '한국사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '한국사') 
    elif '금형' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '금형') 
    elif '냉동' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '냉동') 
    elif '네트워크관' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '네트워크관')
    elif '대형면허' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '대형면허') 
    elif '메이' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '메이') 
    elif '무술유단자' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '무술유단자') 
    elif '섬유' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '섬유') 
    elif '속기사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '속기사') 
    elif '열관리' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '열관리')
    elif '유리시공' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '유리시공') 
    elif '유아' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '유아') 
    elif '의지보조기' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '의지보조기') 
    elif '작업치료사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '작업치료사') 
    elif '지도자' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '지도자') 
    elif '치기공사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '치기공사')
    elif '토익' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '토익') 
    elif '학사' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '학사') 
    elif '한지' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '한지') 
    elif '조종사자격증' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '조종사자격증') 
    elif '호텔' in values:
        test_2018['bq4_1b'] = test_2018['bq4_1b'].str.replace(values, '호텔')
# Out:
# 100%|██████████| 9069/9069 [00:05<00:00, 1522.63it/s]

# %%
for col in train_2018['bq4_1b'].value_counts().loc[train_2018['bq4_1b'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq4_1b'] == col, 'bq4_1b' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq4_1b'].value_counts().index) - set(train_2018['bq4_1b'].value_counts().loc[train_2018['bq4_1b'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq4_1b'] == col, 'bq4_1b_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq4_1c'] = train_2018['bq4_1c'].astype(str)

train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(' ', '')
train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(')', '')
train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace('(', '')
train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace('모름', '없음')
train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace('없다', '없음')

train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace('가능사', '')
train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace('기사', '')

# %%
for values in tqdm(train_2018['bq4_1c']):
    if '한의사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '한의사')
    elif '의사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '의사')
    elif '정보처리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정보처리')
    elif '전기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '전기')
    elif '변호사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '변호사')
    elif '간호' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '간호사')
    elif '회계' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '회계')
    elif '환경' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '환경')
    elif '전문의' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '의사')
    elif '세무사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '세무사')
    elif '교통' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '교통')
    elif '중개' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '부동산')
    elif '사회복지' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '사회복지')   
    elif '부동산' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '부동산')   
    elif '정비' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정비')   
    elif '양식' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '양식')   
    elif '일식' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '일식')
    elif '한식' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '한식')
    elif '중식' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '중식')
    elif '변리사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '변리사')   
    elif '정비' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정비')
    elif '토목' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '토목')
    elif '약사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '약사')
    elif '아동' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '아동')
    elif '유치원' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '아동')        
    elif '정교사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정교사')
    elif '운전면허' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '운전면허')
    elif '노무사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '노무사')
    elif '초등교사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '교원자격증')
    elif '중등교' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '교원자격증')      
    elif '1종' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '1종')
    elif 'CAD' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, 'CAD')        
    elif '택시' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '택시')
    elif '건설기계' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건설기계')
    elif '경기지도사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '경기지도사')
    elif '미용' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '미용')
    elif '교원' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '교원자격증')       
    elif '공무원' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '공무원')
    elif '금융' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '금융')        
    elif '기록' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '기록')
    elif '레크레이션' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '레크레이션')
    elif '물리치료' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '물리치료')
    elif '미용' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '미용')
    elif '방사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '방사')   
    elif '보일러' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '보일러')        
    elif '비파괴' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '비파괴')
    elif '사진' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '사진')
    elif '소방설비' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '소방설비')
    elif '수질' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '수질')
    elif '승강기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '승강기')   
    elif '실내건축' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '실내건축')   
    elif '워드프로' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '워드프로')        
    elif '의료보조' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '의료보조')
    elif '전자상거래' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '전자상거래')
    elif '정보통신' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정보통신')
    elif '수질' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '수질')
    elif '승강기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '승강기')   
    elif '교사자격' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '교원')
    elif '국내여행' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '국내여행')
    elif '코디네이터' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '코디네이터')
    elif '굴삭기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '굴삭기')
    elif '귀금속' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '귀금속')   
    elif '기계설계' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '기계설계')
    elif '메이크업' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '메이크업')
    elif '바리스타' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '바리스타')
    elif '박사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '박사')
    elif '보육교사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '보육교사')   
    elif '산림경영' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '산림경영')
    elif '코디네이터' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '코디네이터')
    elif '산업안전' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '산업안전')
    elif '생활체육' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '생활체육')   
    elif '석사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '석사')
    elif '제과' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '제과')
    elif '조경' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '조경')
    elif '제빵' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '제빵')
    elif '지게차' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '지게차')       
    elif '청소년' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '청소년')
    elif '치과' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '치과')
    elif '컨벤션' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '컨벤션')        
    elif '컴퓨터그래픽' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '컴퓨터그래픽')       
    elif '태권도' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '태권도')
    elif '해기사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '해기사')
    elif '화물운송' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '화물운송') 
    elif '화학분석' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '화학분석')         
    elif '가스' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '가스')        
    elif '가이드' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '가이드')       
    elif '건설재료' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건설재료')
    elif '공조냉동' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '공조냉동')
    elif '관광통역' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '관광통역') 
    elif '기계설비' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '기계설비')    
    elif '놀이' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '놀이')       
    elif '바둑' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '바둑')
    elif '방송통신' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '방송통신')
    elif '베이비' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '베이비') 
    elif '보험' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '보험') 
    elif '소음진동' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '소음진동')
    elif '식품' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '식품')
    elif '언어재활' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '언어재활') 
    elif '영양사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '영양사') 
    elif '용접' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '용접') 
    elif '웹디자인' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '웹디자인') 
    elif '위험물' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '위험물') 
    elif '응급구조' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '응급구조') 
    elif '임상병리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '임상병리') 
    elif '임상심리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '임상심리') 

    elif '건설기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건설기') 
    elif '건축감리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건축감리') 
    elif '건축목' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건축목') 
    elif '경비' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '경비') 
    elif 'KOLAS' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, 'KOLAS') 
    elif '관세사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '관세사') 
    elif '국외여행인솔자' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '국외여행인솔자') 
    elif '기계관련' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '기계관련')        
    elif '네일아트' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '네일아트') 
    elif '드론' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '드론') 
    elif '마술' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '마술') 
    elif '무대예술' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '무대예술') 
    elif '무선설비' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '무선설비') 
    elif '문화재수리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '문화재수리') 
    elif '미술' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '미술') 
    elif '박물관' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '박물관')      
    elif '배관' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '배관') 
    elif '비서' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '비서') 
    elif '산림' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '산림') 
    elif '생활스포츠' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '생활스포츠') 
    elif '설계' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '설계') 
    elif '세탁' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '세탁') 
    elif '소방' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '소방') 
    elif '심리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '심리')       
    elif '에너지' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '에너지') 
    elif '열관리기능' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '열관리기능') 
    elif '캐드' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, 'CAD') 
    elif '요양' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '요양') 
    elif '운송용' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '운송용') 
    elif '인명' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '인명') 
    elif '자동차' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '자동차') 
    elif '전산응용' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '전산응용')   
    elif '정보보안' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정보보안') 
    elif '정보시스템' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정보시스템') 
    elif '정수' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정수') 
    elif '조주' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '조주') 
    elif '직업상담' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '직업상담') 
    elif '초경량' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '초경량') 
    elif '측량' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '측량') 
    elif '컴퓨터' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '컴퓨터') 
        
    elif '투자' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '투자')   
    elif '품질' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '품질') 
    elif '한글' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '한글') 
    elif '항해' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '항해') 
    elif '화약' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '화약') 
    elif '화훼' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '화훼') 
    elif '패턴' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '패턴') 
    elif '한의' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '한의') 
    elif '한약' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '한약') 
    elif '피부관리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '피부관리')         
    elif '정교' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정교사') 
    elif '건축기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건축기') 
    elif '국내심판' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '국내심판') 
    elif '국내A' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '국내심판') 
    elif '문화예술' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '문화예술') 
    elif '방과후' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '방과후') 
    elif '보석' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '보석') 
    elif '보육교' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '보육교') 
    elif '옥외광고' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '옥외광고') 
    elif '외환' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '외환') 
    elif '워드' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '워드') 
    elif '원동기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '원동기') 
    elif '유통관리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '유통관리') 
    elif '일본어' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '일본어') 
        
    elif '전산세무' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '전산세무') 
    elif '전자기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '전자기') 
    elif '철도차량' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '철도차량') 
    elif '교감' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '교감') 
    elif '교장' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '교장') 
    elif '폐기물' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '폐기물') 
    elif '한의' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '한의사') 
    elif '회복지' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '사회복지') 
    elif '항공종' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '항공종') 
    elif '특수분장' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '특수분장') 
    elif '특수학교' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '특수학교') 
    elif '특수교' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '특수학교') 
    elif '피부' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '피부') 

    elif 'GTQ' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, 'GTQ') 
    elif 'SQL' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, 'SQL') 
    elif '건설' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건설') 
    elif '건축구조' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건축구조') 
    elif '건축도장' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건축도장') 
    elif '건축설비' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '건축설비') 
    elif '게임프로그래밍' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '게임프로그래밍') 
    elif '경기지도' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '경기지도') 
    elif '경매사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '경매사') 
    elif '경영지도' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '경영지도') 
    elif '경찰' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '경찰') 
    elif '관제' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '관제') 
    elif '광고' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '광고') 
    elif '광산' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '광산') 
    elif '국제무역' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '국제무역') 
    elif '그래픽' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '그래픽') 
    elif '금속공' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '금속공') 
    elif '금속재료' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '금속재료') 
    elif '도시계획' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '도시계획') 
    elif '반도체' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '반도체') 
    elif '보건교사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '보건교사') 
    elif '보건의료' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '보건의료') 
    elif '복지' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '사회복지')        
    elif '빅데이터' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '빅데이터') 
    elif '사서' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '사서') 
    elif '소잉디자이너' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '소잉디자이너') 
    elif '소프트웨어' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '소프트웨어') 
    elif '스포츠' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '스포츠') 
    elif '시각디자' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '시각디자인') 
    elif '신용' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '신용') 
    elif '실내디자인' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '실내디자인') 
    elif '심판' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '심판') 
    elif '악기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '악기') 
    elif '안경' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '안경')                
    elif '안마' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '안마') 
    elif '언어' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '언어') 
    elif '워드' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '워드') 
    elif '전자계산' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '전자계산') 
    elif '정사서' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '정사서') 
    elif '조리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '조리') 
    elif '지적' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '지적') 
    elif '통신선로' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '통신선로') 
    elif '판금' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '판금') 
    elif '펀드' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '펀드')
    elif '펄프' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '펄프') 
    elif '피아노조율' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '피아노조율') 
    elif '한국사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '한국사') 
    elif '금형' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '금형') 
    elif '냉동' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '냉동') 
    elif '네트워크관' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '네트워크관')
    elif '대형면허' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '대형면허') 
    elif '메이' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '메이') 
    elif '무술유단자' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '무술유단자') 
    elif '섬유' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '섬유') 
    elif '속기사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '속기사') 
    elif '열관리' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '열관리')
    elif '유리시공' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '유리시공') 
    elif '유아' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '유아') 
    elif '의지보조기' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '의지보조기') 
    elif '작업치료사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '작업치료사') 
    elif '지도자' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '지도자') 
    elif '치기공사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '치기공사')
    elif '토익' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '토익') 
    elif '학사' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '학사') 
    elif '한지' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '한지') 
    elif '조종사자격증' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '조종사자격증') 
    elif '호텔' in values:
        train_2018['bq4_1c'] = train_2018['bq4_1c'].str.replace(values, '호텔')
# Out:
# 100%|██████████| 9072/9072 [00:01<00:00, 6900.99it/s]

# %%
for col in train_2018['bq4_1c'].value_counts().loc[train_2018['bq4_1c'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq4_1c'] == col, 'bq4_1c' + col] = 1
    train_2018 = train_2018.fillna(0)

for col in train_2018['bq4_1c'].value_counts().loc[train_2018['bq4_1c'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq4_1c'] == col, 'bq4_1c_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq4_1c'] = test_2018['bq4_1c'].astype(str)

test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(' ', '')
test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(')', '')
test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace('(', '')
test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace('모름', '없음')
test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace('없다', '없음')

test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace('가능사', '')
test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace('기사', '')

# %%
for values in tqdm(test_2018['bq4_1c']):
    if '한의사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '한의사')
    elif '의사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '의사')
    elif '정보처리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정보처리')
    elif '전기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '전기')
    elif '변호사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '변호사')
    elif '간호' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '간호사')
    elif '회계' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '회계')
    elif '환경' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '환경')
    elif '전문의' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '의사')
    elif '세무사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '세무사')
    elif '교통' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '교통')
    elif '중개' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '부동산')
    elif '사회복지' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '사회복지')   
    elif '부동산' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '부동산')   
    elif '정비' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정비')   
    elif '양식' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '양식')   
    elif '일식' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '일식')
    elif '한식' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '한식')
    elif '중식' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '중식')
    elif '변리사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '변리사')   
    elif '정비' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정비')
    elif '토목' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '토목')
    elif '약사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '약사')
    elif '아동' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '아동')
    elif '유치원' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '아동')        
    elif '정교사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정교사')
    elif '운전면허' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '운전면허')
    elif '노무사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '노무사')
    elif '초등교사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '교원자격증')
    elif '중등교' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '교원자격증')      
    elif '1종' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '1종')
    elif 'CAD' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, 'CAD')        
    elif '택시' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '택시')
    elif '건설기계' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건설기계')
    elif '경기지도사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '경기지도사')
    elif '미용' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '미용')
    elif '교원' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '교원자격증')       
    elif '공무원' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '공무원')
    elif '금융' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '금융')        
    elif '기록' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '기록')
    elif '레크레이션' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '레크레이션')
    elif '물리치료' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '물리치료')
    elif '미용' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '미용')
    elif '방사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '방사')   
    elif '보일러' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '보일러')        
    elif '비파괴' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '비파괴')
    elif '사진' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '사진')
    elif '소방설비' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '소방설비')
    elif '수질' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '수질')
    elif '승강기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '승강기')   
    elif '실내건축' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '실내건축')   
    elif '워드프로' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '워드프로')        
    elif '의료보조' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '의료보조')
    elif '전자상거래' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '전자상거래')
    elif '정보통신' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정보통신')
    elif '수질' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '수질')
    elif '승강기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '승강기')   
    elif '교사자격' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '교원')
    elif '국내여행' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '국내여행')
    elif '코디네이터' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '코디네이터')
    elif '굴삭기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '굴삭기')
    elif '귀금속' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '귀금속')   
    elif '기계설계' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '기계설계')
    elif '메이크업' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '메이크업')
    elif '바리스타' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '바리스타')
    elif '박사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '박사')
    elif '보육교사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '보육교사')   
    elif '산림경영' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '산림경영')
    elif '코디네이터' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '코디네이터')
    elif '산업안전' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '산업안전')
    elif '생활체육' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '생활체육')   
    elif '석사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '석사')
    elif '제과' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '제과')
    elif '조경' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '조경')
    elif '제빵' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '제빵')
    elif '지게차' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '지게차')       
    elif '청소년' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '청소년')
    elif '치과' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '치과')
    elif '컨벤션' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '컨벤션')        
    elif '컴퓨터그래픽' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '컴퓨터그래픽')       
    elif '태권도' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '태권도')
    elif '해기사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '해기사')
    elif '화물운송' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '화물운송') 
    elif '화학분석' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '화학분석')         
    elif '가스' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '가스')        
    elif '가이드' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '가이드')       
    elif '건설재료' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건설재료')
    elif '공조냉동' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '공조냉동')
    elif '관광통역' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '관광통역') 
    elif '기계설비' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '기계설비')    
    elif '놀이' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '놀이')       
    elif '바둑' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '바둑')
    elif '방송통신' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '방송통신')
    elif '베이비' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '베이비') 
    elif '보험' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '보험') 
    elif '소음진동' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '소음진동')
    elif '식품' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '식품')
    elif '언어재활' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '언어재활') 
    elif '영양사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '영양사') 
    elif '용접' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '용접') 
    elif '웹디자인' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '웹디자인') 
    elif '위험물' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '위험물') 
    elif '응급구조' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '응급구조') 
    elif '임상병리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '임상병리') 
    elif '임상심리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '임상심리') 

    elif '건설기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건설기') 
    elif '건축감리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건축감리') 
    elif '건축목' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건축목') 
    elif '경비' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '경비') 
    elif 'KOLAS' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, 'KOLAS') 
    elif '관세사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '관세사') 
    elif '국외여행인솔자' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '국외여행인솔자') 
    elif '기계관련' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '기계관련')        
    elif '네일아트' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '네일아트') 
    elif '드론' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '드론') 
    elif '마술' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '마술') 
    elif '무대예술' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '무대예술') 
    elif '무선설비' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '무선설비') 
    elif '문화재수리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '문화재수리') 
    elif '미술' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '미술') 
    elif '박물관' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '박물관')      
    elif '배관' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '배관') 
    elif '비서' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '비서') 
    elif '산림' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '산림') 
    elif '생활스포츠' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '생활스포츠') 
    elif '설계' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '설계') 
    elif '세탁' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '세탁') 
    elif '소방' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '소방') 
    elif '심리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '심리')       
    elif '에너지' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '에너지') 
    elif '열관리기능' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '열관리기능') 
    elif '캐드' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, 'CAD') 
    elif '요양' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '요양') 
    elif '운송용' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '운송용') 
    elif '인명' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '인명') 
    elif '자동차' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '자동차') 
    elif '전산응용' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '전산응용')   
    elif '정보보안' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정보보안') 
    elif '정보시스템' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정보시스템') 
    elif '정수' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정수') 
    elif '조주' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '조주') 
    elif '직업상담' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '직업상담') 
    elif '초경량' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '초경량') 
    elif '측량' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '측량') 
    elif '컴퓨터' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '컴퓨터') 
        
    elif '투자' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '투자')   
    elif '품질' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '품질') 
    elif '한글' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '한글') 
    elif '항해' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '항해') 
    elif '화약' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '화약') 
    elif '화훼' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '화훼') 
    elif '패턴' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '패턴') 
    elif '한의' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '한의') 
    elif '한약' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '한약') 
    elif '피부관리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '피부관리')         
    elif '정교' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정교사') 
    elif '건축기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건축기') 
    elif '국내심판' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '국내심판') 
    elif '국내A' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '국내심판') 
    elif '문화예술' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '문화예술') 
    elif '방과후' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '방과후') 
    elif '보석' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '보석') 
    elif '보육교' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '보육교') 
    elif '옥외광고' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '옥외광고') 
    elif '외환' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '외환') 
    elif '워드' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '워드') 
    elif '원동기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '원동기') 
    elif '유통관리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '유통관리') 
    elif '일본어' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '일본어') 
        
    elif '전산세무' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '전산세무') 
    elif '전자기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '전자기') 
    elif '철도차량' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '철도차량') 
    elif '교감' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '교감') 
    elif '교장' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '교장') 
    elif '폐기물' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '폐기물') 
    elif '한의' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '한의사') 
    elif '회복지' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '사회복지') 
    elif '항공종' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '항공종') 
    elif '특수분장' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '특수분장') 
    elif '특수학교' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '특수학교') 
    elif '특수교' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '특수학교') 
    elif '피부' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '피부') 

    elif 'GTQ' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, 'GTQ') 
    elif 'SQL' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, 'SQL') 
    elif '건설' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건설') 
    elif '건축구조' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건축구조') 
    elif '건축도장' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건축도장') 
    elif '건축설비' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '건축설비') 
    elif '게임프로그래밍' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '게임프로그래밍') 
    elif '경기지도' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '경기지도') 
    elif '경매사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '경매사') 
    elif '경영지도' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '경영지도') 
    elif '경찰' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '경찰') 
    elif '관제' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '관제') 
    elif '광고' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '광고') 
    elif '광산' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '광산') 
    elif '국제무역' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '국제무역') 
    elif '그래픽' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '그래픽') 
    elif '금속공' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '금속공') 
    elif '금속재료' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '금속재료') 
    elif '도시계획' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '도시계획') 
    elif '반도체' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '반도체') 
    elif '보건교사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '보건교사') 
    elif '보건의료' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '보건의료') 
    elif '복지' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '사회복지')        
    elif '빅데이터' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '빅데이터') 
    elif '사서' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '사서') 
    elif '소잉디자이너' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '소잉디자이너') 
    elif '소프트웨어' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '소프트웨어') 
    elif '스포츠' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '스포츠') 
    elif '시각디자' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '시각디자인') 
    elif '신용' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '신용') 
    elif '실내디자인' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '실내디자인') 
    elif '심판' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '심판') 
    elif '악기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '악기') 
    elif '안경' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '안경')                
    elif '안마' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '안마') 
    elif '언어' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '언어') 
    elif '워드' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '워드') 
    elif '전자계산' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '전자계산') 
    elif '정사서' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '정사서') 
    elif '조리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '조리') 
    elif '지적' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '지적') 
    elif '통신선로' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '통신선로') 
    elif '판금' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '판금') 
    elif '펀드' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '펀드')
    elif '펄프' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '펄프') 
    elif '피아노조율' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '피아노조율') 
    elif '한국사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '한국사') 
    elif '금형' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '금형') 
    elif '냉동' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '냉동') 
    elif '네트워크관' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '네트워크관')
    elif '대형면허' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '대형면허') 
    elif '메이' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '메이') 
    elif '무술유단자' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '무술유단자') 
    elif '섬유' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '섬유') 
    elif '속기사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '속기사') 
    elif '열관리' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '열관리')
    elif '유리시공' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '유리시공') 
    elif '유아' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '유아') 
    elif '의지보조기' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '의지보조기') 
    elif '작업치료사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '작업치료사') 
    elif '지도자' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '지도자') 
    elif '치기공사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '치기공사')
    elif '토익' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '토익') 
    elif '학사' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '학사') 
    elif '한지' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '한지') 
    elif '조종사자격증' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '조종사자격증') 
    elif '호텔' in values:
        test_2018['bq4_1c'] = test_2018['bq4_1c'].str.replace(values, '호텔')
# Out:
# 100%|██████████| 9069/9069 [00:01<00:00, 6394.94it/s]

# %%
for col in train_2018['bq4_1c'].value_counts().loc[train_2018['bq4_1c'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq4_1c'] == col, 'bq4_1c' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq4_1c'].value_counts().index) - set(train_2018['bq4_1c'].value_counts().loc[train_2018['bq4_1c'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq4_1c'] == col, 'bq4_1c_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq29'] = train_2018['bq29'].astype(str)

train_2018['bq29'] = train_2018['bq29'].str.replace(' ', '')
train_2018['bq29'] = train_2018['bq29'].str.replace(')', '')
train_2018['bq29'] = train_2018['bq29'].str.replace('(', '')
train_2018['bq29'] = train_2018['bq29'].str.replace('모름', '없음')
train_2018['bq29'] = train_2018['bq29'].str.replace('없다', '없음')
train_2018['bq29'] = train_2018['bq29'].str.replace('님', '')

# %%
for values in tqdm(train_2018['bq29']):
    if '기사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '기사')
    elif '이발' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '디자이너')
    elif '의사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '의사')
    elif '선생' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '선생')
    elif '교사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '선생')
    elif '쌤' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '선생')
    elif '강사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '선생')
    elif '간호' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '간호사')
    elif '정비' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '정비사')
    elif '관제' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '관제사')
    elif '없' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '없음')
    elif '119' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '119')
    elif 'CPA' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, 'CPA')
    elif '회계사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, 'CPA')
    elif 'PD' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, 'PD')
    elif '프로듀서' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, 'PD')
    elif '감독' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, 'PD')
    elif '검사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '검사')
    elif '게임' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '게임')
    elif '교도관' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '교도관')
    elif '구두' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '구두')
    elif '노가' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '노가다')
    elif '담배' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '담배')
    elif '도우미' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '도우미')
    elif '동물' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '동물')
    elif '매니저' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '매니저')
    elif '목재' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '목재')
    elif '미용사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '미용사')
    elif '박사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '박사')
    elif '배달' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '배달')
    elif '병원' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '병원')
    elif '보석' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '보석')
    elif '보험' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '보험')
    elif '복덕방' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '복덕방')
    elif '비파괴' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '비파괴')
    elif '상담' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '상담')
    elif '설계' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '설계')
    elif '소방' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '소방')
    elif '엔지니어' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '엔지니어')
    elif '연구' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '연구')
    elif '영업' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '영업')
    elif '요리사' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '요리사')
    elif '음향' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '음향')
    elif '전기' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '전기')
    elif '직업' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '직업')
    elif '판매' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '판매')
    elif '펀드매니저' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '펀드매니저')

    elif '3D' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '3D')
    elif 'CAD' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, 'CAD')
    elif '감리' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '감리')
    elif '개발' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '개발')
    elif '공무원' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '공무원')
    elif '관리' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '관리')
    elif '구조' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '구조')
    elif '데이터' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '데이터')
    elif '드론' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '드론')
    elif '마케' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '마케')
    elif '모델' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '모델')
    elif '무용' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '무용')
    elif '작가' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '작가')
    elif '배관' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '배관')
    elif '배우' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '배우')
    elif '번역' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '번역')
    elif '부동산' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '부동산')
    elif '사장' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '사장')
    elif '배관' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '배관')
    elif '배우' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '배우')
    elif '스튜' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '승무원')
    elif '승무원' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '승무원')
    elif '엑셀' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '엑셀')
    elif '연예인' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '연예인')
    elif '오퍼레이터' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '오퍼레이터')
    elif '조종' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '조종')
    elif '주방' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '주방')
    elif '직급' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '직급')
    elif '프로그' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '프로그')
    elif '편집' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '편집')
    elif '통역' in values:
        train_2018['bq29'] = train_2018['bq29'].str.replace(values, '통역')
# Out:
# 100%|██████████| 9072/9072 [00:50<00:00, 179.61it/s]

# %%
for col in train_2018['bq29'].value_counts().loc[train_2018['bq29'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq29'] == col, 'bq29' + col] = 1
    train_2018 = train_2018.fillna(0)         

for col in train_2018['bq29'].value_counts().loc[train_2018['bq29'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq29'] == col, 'bq29_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq29'] = test_2018['bq29'].astype(str)

test_2018['bq29'] = test_2018['bq29'].str.replace(' ', '')
test_2018['bq29'] = test_2018['bq29'].str.replace(')', '')
test_2018['bq29'] = test_2018['bq29'].str.replace('(', '')
test_2018['bq29'] = test_2018['bq29'].str.replace('모름', '없음')
test_2018['bq29'] = test_2018['bq29'].str.replace('없다', '없음')
test_2018['bq29'] = test_2018['bq29'].str.replace('님', '')

# %%
for values in tqdm(test_2018['bq29']):
    if '기사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '기사')
    elif '이발' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '디자이너')
    elif '의사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '의사')
    elif '선생' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '선생')
    elif '교사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '선생')
    elif '쌤' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '선생')
    elif '강사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '선생')
    elif '간호' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '간호사')
    elif '정비' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '정비사')
    elif '관제' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '관제사')
    elif '없' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '없음')
    elif '119' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '119')
    elif 'CPA' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, 'CPA')
    elif '회계사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, 'CPA')
    elif 'PD' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, 'PD')
    elif '프로듀서' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, 'PD')
    elif '감독' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, 'PD')
    elif '검사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '검사')
    elif '게임' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '게임')
    elif '교도관' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '교도관')
    elif '구두' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '구두')
    elif '노가' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '노가다')
    elif '담배' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '담배')
    elif '도우미' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '도우미')
    elif '동물' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '동물')
    elif '매니저' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '매니저')
    elif '목재' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '목재')
    elif '미용사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '미용사')
    elif '박사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '박사')
    elif '배달' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '배달')
    elif '병원' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '병원')
    elif '보석' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '보석')
    elif '보험' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '보험')
    elif '복덕방' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '복덕방')
    elif '비파괴' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '비파괴')
    elif '상담' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '상담')
    elif '설계' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '설계')
    elif '소방' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '소방')
    elif '엔지니어' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '엔지니어')
    elif '연구' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '연구')
    elif '영업' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '영업')
    elif '요리사' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '요리사')
    elif '음향' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '음향')
    elif '전기' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '전기')
    elif '직업' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '직업')
    elif '판매' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '판매')
    elif '펀드매니저' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '펀드매니저')

    elif '3D' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '3D')
    elif 'CAD' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, 'CAD')
    elif '감리' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '감리')
    elif '개발' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '개발')
    elif '공무원' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '공무원')
    elif '관리' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '관리')
    elif '구조' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '구조')
    elif '데이터' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '데이터')
    elif '드론' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '드론')
    elif '마케' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '마케')
    elif '모델' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '모델')
    elif '무용' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '무용')
    elif '작가' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '작가')
    elif '배관' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '배관')
    elif '배우' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '배우')
    elif '번역' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '번역')
    elif '부동산' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '부동산')
    elif '사장' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '사장')
    elif '배관' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '배관')
    elif '배우' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '배우')
    elif '스튜' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '승무원')
    elif '승무원' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '승무원')
    elif '엑셀' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '엑셀')
    elif '연예인' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '연예인')
    elif '오퍼레이터' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '오퍼레이터')
    elif '조종' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '조종')
    elif '주방' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '주방')
    elif '직급' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '직급')
    elif '프로그' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '프로그')
    elif '편집' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '편집')
    elif '통역' in values:
        test_2018['bq29'] = test_2018['bq29'].str.replace(values, '통역')
# Out:
# 100%|██████████| 9069/9069 [00:50<00:00, 180.12it/s]

# %%
for col in train_2018['bq29'].value_counts().loc[train_2018['bq29'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq29'] == col, 'bq29' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq29'].value_counts().index) - set(train_2018['bq29'].value_counts().loc[train_2018['bq29'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq29'] == col, 'bq29_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq30'] = train_2018['bq30'].astype(str)

train_2018['bq30'] = train_2018['bq30'].str.replace(' ', '')
train_2018['bq30'] = train_2018['bq30'].str.replace(')', '')
train_2018['bq30'] = train_2018['bq30'].str.replace('(', '')
train_2018['bq30'] = train_2018['bq30'].str.replace(',', '')
train_2018['bq30'] = train_2018['bq30'].str.replace('+', '')
train_2018['bq30'] = train_2018['bq30'].str.replace('모름', '없음')
train_2018['bq30'] = train_2018['bq30'].str.replace('없다', '없음')
train_2018['bq30'] = train_2018['bq30'].str.replace('/', '')

# %%
for values in tqdm(train_2018['bq30']):
    if '엑셀' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '엑셀')
    elif '포토샵' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '포토샵')
    elif '컴퓨터' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '컴퓨터')
    elif '노트북' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '컴퓨터')
    elif '공구' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '공구')
    elif 'pc' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '컴퓨터')
    elif 'PC' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '컴퓨터')
    elif '수신기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '무전기')        
    elif '캐드' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'CAD')        
    elif '도마' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '칼') 

    elif 'CAD' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'CAD')
    elif 'CNC' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'CNC')
    elif 'EMR' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'EMR')
    elif 'ERP' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'ERP')
    elif 'EXCEL' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '엑셀')
    elif 'HTML' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'HTML')
    elif 'JAVA' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'JAVA')        
    elif 'MS' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'MS')        
    elif 'Ms' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'Ms')         
    elif 'PDA' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'PDA')
    elif 'SPSS' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'SPSS')
    elif 'X-ray' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'X-ray')
    elif 'X-Ray' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'X-ray')
    elif '가스총' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '가스총')
    elif '가열기계' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '가열기계')
    elif '가야금' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '가야금')        
    elif '가위' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '가위')        
    elif '교재' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '교재')                 
    elif '양념' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '양념')
    elif '케드' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'CAD')
    elif '경운기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '경운기')
    elif '계산기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '계산기')
    elif '고객' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '고객')
    elif '공기총' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '공기총')
    elif '가야금' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '가야금')        
    elif '공연' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '공연')        
    elif '관제' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '관제')        
    elif '교과서' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '교재')
    elif '굴삭기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '굴삭기')
    elif '그라인더' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '그라인더')
    elif '금형틀' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '금형틀')
    elif '나이스' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '나이스')
    elif '내시경' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '내시경')
    elif '냄비' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '냄비')        
    elif '네트워크' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '네트워크')        
    elif '녹음' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '녹음')  
    elif '농구' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '농구')
    elif '농기구' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '농기구')
    elif '농사기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '농기구')
    elif '니퍼' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '니퍼')
    elif '다리미' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '다리미')
    elif '담배' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '담배')
    elif '대본' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '대본')        
    elif '주사기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '주사기')        
    elif '진료' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '진료')   
    elif '청진기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '청진기')
    elif '초음파' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '초음파')
    elif '축구' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '축구')
    elif '카메라' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '카메라')
    elif '커피' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '커피')
    elif '통계프로그램' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'SPSS')
    elif '파워포인트' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '파워포인트')        
    elif '포스기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '포스기')        
    elif '피아노' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '피아노')    
    elif '한글' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '한글')
    elif '현미경' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '현미경')
    elif '혈압' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '축구')
    elif '골프' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '골프')
    elif '환자' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '환자')
    elif '호루라기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '호루라기')

    elif '절단기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '절단기')    
    elif '전산회계' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '전산회계')
    elif '장갑' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '장갑')
    elif '잠수' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '잠수')
    elif '스패너' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '스패너')
    elif 'C언어' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'C언어')
    elif 'Cad' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'CAD')
    elif 'Python' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'Python')    
    elif 'VOCVHF' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'VOCVHF')
    elif 'Visual' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'Visual')
    elif 'spss' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'SPSS')
    elif 'visual' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, 'Visual')
    elif '계측기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '계측기')
    elif '구명조끼' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '구명조끼')

    elif '네비' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '네비')    
    elif '그릇' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '그릇')
    elif '놀이기구' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '놀이기구')
    elif '농기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '농기')
    elif '더존' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '더존')
    elif '도면' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '도면')
    elif '도서' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '도서')
    elif '드라이버' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '드라이버')    
    elif '드론' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '드론')
    elif '드릴' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '드라이버')
    elif '마이크' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '마이크')
    elif '마이크로' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '마이크로')
    elif '화장품' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '화장품')
    elif '호미' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '호미')
        
    elif '헬리콥터' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '헬리콥터')    
    elif '핸드폰' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '핸드폰')
    elif '프로그' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '프로그')
    elif '포장기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '포장기')
    elif '파이널컷' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '파이널컷')
    elif '트렉터' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '트렉터')
    elif '클라우드' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '클라우드')
    elif '측정장비' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '측정장비')    
    elif '측정기' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '측정장비')
    elif '체온계' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '체온계')
    elif '청소' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '청소')
    elif '청력' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '청력')
    elif '직조' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '직조')
    elif '줄자' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '줄자')
    elif '조명' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '조명')
    elif '전산프로그' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '전산프로그')
    elif '적외선' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '적외선')
    elif '재활프로' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '재활프로')
    elif '재봉틀' in values:
        train_2018['bq30'] = train_2018['bq30'].str.replace(values, '재봉틀')
# Out:
# 100%|██████████| 9072/9072 [00:37<00:00, 243.26it/s]

# %%
for col in train_2018['bq30'].value_counts().loc[train_2018['bq30'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq30'] == col, 'bq30' + col] = 1
    train_2018 = train_2018.fillna(0)         

for col in train_2018['bq30'].value_counts().loc[train_2018['bq30'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq30'] == col, 'bq30_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq30'] = test_2018['bq30'].astype(str)

test_2018['bq30'] = test_2018['bq30'].str.replace(' ', '')
test_2018['bq30'] = test_2018['bq30'].str.replace(')', '')
test_2018['bq30'] = test_2018['bq30'].str.replace('(', '')
test_2018['bq30'] = test_2018['bq30'].str.replace(',', '')
test_2018['bq30'] = test_2018['bq30'].str.replace('+', '')
test_2018['bq30'] = test_2018['bq30'].str.replace('모름', '없음')
test_2018['bq30'] = test_2018['bq30'].str.replace('없다', '없음')
test_2018['bq30'] = test_2018['bq30'].str.replace("\\", '')

# %%
for values in tqdm(test_2018['bq30']):
    if '엑셀' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '엑셀')
    elif '포토샵' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '포토샵')
    elif '컴퓨터' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '컴퓨터')
    elif '노트북' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '컴퓨터')
    elif '공구' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '공구')
    elif 'pc' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '컴퓨터')
    elif 'PC' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '컴퓨터')
    elif '수신기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '무전기')        
    elif '캐드' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'CAD')        
    elif '도마' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '칼') 

    elif 'CAD' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'CAD')
    elif 'CNC' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'CNC')
    elif 'EMR' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'EMR')
    elif 'ERP' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'ERP')
    elif 'EXCEL' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '엑셀')
    elif 'HTML' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'HTML')
    elif 'JAVA' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'JAVA')        
    elif 'MS' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'MS')        
    elif 'Ms' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'Ms')         
    elif 'PDA' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'PDA')
    elif 'SPSS' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'SPSS')
    elif 'X-ray' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'X-ray')
    elif 'X-Ray' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'X-ray')
    elif '가스총' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '가스총')
    elif '가열기계' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '가열기계')
    elif '가야금' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '가야금')        
    elif '가위' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '가위')        
    elif '교재' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '교재')                 
    elif '양념' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '양념')
    elif '케드' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'CAD')
    elif '경운기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '경운기')
    elif '계산기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '계산기')
    elif '고객' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '고객')
    elif '공기총' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '공기총')
    elif '가야금' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '가야금')        
    elif '공연' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '공연')        
    elif '관제' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '관제')        
    elif '교과서' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '교재')
    elif '굴삭기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '굴삭기')
    elif '그라인더' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '그라인더')
    elif '금형틀' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '금형틀')
    elif '나이스' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '나이스')
    elif '내시경' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '내시경')
    elif '냄비' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '냄비')        
    elif '네트워크' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '네트워크')        
    elif '녹음' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '녹음')  
    elif '농구' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '농구')
    elif '농기구' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '농기구')
    elif '농사기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '농기구')
    elif '니퍼' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '니퍼')
    elif '다리미' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '다리미')
    elif '담배' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '담배')
    elif '대본' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '대본')        
    elif '주사기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '주사기')        
    elif '진료' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '진료')   
    elif '청진기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '청진기')
    elif '초음파' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '초음파')
    elif '축구' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '축구')
    elif '카메라' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '카메라')
    elif '커피' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '커피')
    elif '통계프로그램' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'SPSS')
    elif '파워포인트' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '파워포인트')        
    elif '포스기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '포스기')        
    elif '피아노' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '피아노')    
    elif '한글' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '한글')
    elif '현미경' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '현미경')
    elif '혈압' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '축구')
    elif '골프' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '골프')
    elif '환자' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '환자')
    elif '호루라기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '호루라기')

    elif '절단기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '절단기')    
    elif '전산회계' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '전산회계')
    elif '장갑' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '장갑')
    elif '잠수' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '잠수')
    elif '스패너' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '스패너')
    elif 'C언어' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'C언어')
    elif 'Cad' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'CAD')
    elif 'Python' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'Python')    
    elif 'VOCVHF' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'VOCVHF')
    elif 'Visual' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'Visual')
    elif 'spss' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'SPSS')
    elif 'visual' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, 'Visual')
    elif '계측기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '계측기')
    elif '구명조끼' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '구명조끼')

    elif '네비' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '네비')    
    elif '그릇' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '그릇')
    elif '놀이기구' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '놀이기구')
    elif '농기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '농기')
    elif '더존' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '더존')
    elif '도면' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '도면')
    elif '도서' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '도서')
    elif '드라이버' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '드라이버')    
    elif '드론' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '드론')
    elif '드릴' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '드라이버')
    elif '마이크' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '마이크')
    elif '마이크로' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '마이크로')
    elif '화장품' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '화장품')
    elif '호미' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '호미')
        
    elif '헬리콥터' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '헬리콥터')    
    elif '핸드폰' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '핸드폰')
    elif '프로그' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '프로그')
    elif '포장기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '포장기')
    elif '파이널컷' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '파이널컷')
    elif '트렉터' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '트렉터')
    elif '클라우드' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '클라우드')
    elif '측정장비' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '측정장비')    
    elif '측정기' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '측정장비')
    elif '체온계' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '체온계')
    elif '청소' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '청소')
    elif '청력' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '청력')
    elif '직조' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '직조')
    elif '줄자' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '줄자')
    elif '조명' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '조명')
    elif '전산프로그' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '전산프로그')
    elif '적외선' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '적외선')
    elif '재활프로' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '재활프로')
    elif '재봉틀' in values:
        test_2018['bq30'] = test_2018['bq30'].str.replace(values, '재봉틀')
# Out:
# 100%|██████████| 9069/9069 [00:38<00:00, 237.91it/s]

# %%
for col in train_2018['bq30'].value_counts().loc[train_2018['bq30'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq30'] == col, 'bq30' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq30'].value_counts().index) - set(train_2018['bq30'].value_counts().loc[train_2018['bq30'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq30'] == col, 'bq30_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %% [markdown]
# ### bq31

# %%
train_2018['bq31'] = train_2018['bq31'].astype(str)

train_2018['bq31'] = train_2018['bq31'].str.replace(' ', '')
train_2018['bq31'] = train_2018['bq31'].str.replace(')', '')
train_2018['bq31'] = train_2018['bq31'].str.replace('(', '')
train_2018['bq31'] = train_2018['bq31'].str.replace(',', '')
train_2018['bq31'] = train_2018['bq31'].str.replace('+', '')
train_2018['bq31'] = train_2018['bq31'].str.replace('모름', '없음')
train_2018['bq31'] = train_2018['bq31'].str.replace('없다', '없음')

# %%
for values in tqdm(train_2018['bq31']):
    if '주부' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '주부')
    elif '군인' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '군인')
    elif '사무원' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '사무직')
    elif '사무직' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '사무직')        
    elif '선장' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '항해사')
    elif '영업' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '영업')
    elif '판매' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '판매')
    elif '경리' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '경리')        
    elif '강사' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '강사')
    elif '교수' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '교수')    
    elif '서비스' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '서비스')  

    elif 'IT' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, 'IT')
    elif '가구' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '가구')
    elif '간호' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '간호')        
    elif '개발' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '개발')
    elif '건설' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '건설')
    elif '건축' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '건축')
    elif '교사' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '교사')        
    elif '금속가공' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '금속가공')
    elif '동일' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '동일')    
    elif '미용' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '미용')  
    elif '버스' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '버스')
    elif '보험' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '보험')
    elif '사무' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '사무')        
    elif '생산' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '생산')
    elif '선생' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '교사')
    elif '섬유' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '섬유')
    elif '식당' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '식당')        
    elif '신발' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '신발')
    elif '없음' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '없음')    
    elif '연구' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '연구')  
        
    elif '외식' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '식당')        
    elif '유통' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '유통')
    elif '음악' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '음악')
    elif '인테리어' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '인테리어')
    elif '자동차' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '자동차')        
    elif '제조업' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '제조업')
    elif '초등' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '초등')    
    elif '회사원' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '회사원') 
        
    elif '회계' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '회계')
    elif '행정' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '행정')
    elif '프로그' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '프로그')
    elif '트럭' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '트럭')        
    elif '택시' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '택시')
    elif '컴퓨터' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '컴퓨터')    
    elif '출판' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '출판')        
    elif '주방' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '주방')

    elif '건물' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '건물')
    elif '그래픽' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '그래픽')
    elif '공무원' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '공무원')
    elif '광고' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '광고')        
    elif '구두' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '구두')
    elif '금융' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '금융')    
    elif '기계조' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '기계조')        
    elif '학생' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '학생')
    elif '마케' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '마케')
    elif '물류' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '물류')
    elif '미술' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '미술')
    elif '방송' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '방송')        
    elif '배달' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '배달')
    elif '보일러' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '보일러')    
    elif '사진' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '사진')        
    elif '신문' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '신문')
    elif '여행' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '여행')
    elif '용접' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '용접')
    elif '웨딩' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '웨딩')
    elif '배달' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '배달')
    elif '음식' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '음식')        
    elif '배달' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '배달')
    elif '의류' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '의류')    
    elif '은행' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '은행')        
    elif '전기' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '전기공')
        
    elif '촬영' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '촬영')
    elif '카메라' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '촬영')
    elif '택배' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '택배')        
    elif '해군' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '해군')
    elif '호텔' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '호텔')    
    elif '휴대폰' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '휴대폰')        
    elif '회사' in values:
        train_2018['bq31'] = train_2018['bq31'].str.replace(values, '회사')
# Out:
# 100%|██████████| 9072/9072 [00:56<00:00, 161.31it/s]

# %%
for col in train_2018['bq31'].value_counts().loc[train_2018['bq31'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq31'] == col, 'bq31' + col] = 1
    train_2018 = train_2018.fillna(0)         

for col in train_2018['bq31'].value_counts().loc[train_2018['bq31'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq31'] == col, 'bq31_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq31'] = test_2018['bq31'].astype(str)

test_2018['bq31'] = test_2018['bq31'].str.replace(' ', '')
test_2018['bq31'] = test_2018['bq31'].str.replace(')', '')
test_2018['bq31'] = test_2018['bq31'].str.replace('(', '')
test_2018['bq31'] = test_2018['bq31'].str.replace('모름', '없음')
test_2018['bq31'] = test_2018['bq31'].str.replace('없다', '없음')
test_2018['bq31'] = test_2018['bq31'].str.replace('님', '')
test_2018['bq31'] = test_2018['bq31'].str.replace('+', '')

# %%
for values in tqdm(test_2018['bq31']):
    if '주부' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '주부')
    elif '군인' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '군인')
    elif '사무원' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '사무직')
    elif '사무직' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '사무직')        
    elif '선장' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '항해사')
    elif '영업' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '영업')
    elif '판매' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '판매')
    elif '경리' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '경리')        
    elif '강사' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '강사')
    elif '교수' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '교수')    
    elif '서비스' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '서비스')  

    elif 'IT' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, 'IT')
    elif '가구' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '가구')
    elif '간호' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '간호')        
    elif '개발' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '개발')
    elif '건설' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '건설')
    elif '건축' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '건축')
    elif '교사' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '교사')        
    elif '금속가공' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '금속가공')
    elif '동일' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '동일')    
    elif '미용' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '미용')  
    elif '버스' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '버스')
    elif '보험' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '보험')
    elif '사무' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '사무')        
    elif '생산' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '생산')
    elif '선생' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '교사')
    elif '섬유' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '섬유')
    elif '식당' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '식당')        
    elif '신발' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '신발')
    elif '없음' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '없음')    
    elif '연구' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '연구')  
        
    elif '외식' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '식당')        
    elif '유통' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '유통')
    elif '음악' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '음악')
    elif '인테리어' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '인테리어')
    elif '자동차' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '자동차')        
    elif '제조업' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '제조업')
    elif '초등' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '초등')    
    elif '회사원' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '회사원') 
        
    elif '회계' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '회계')
    elif '행정' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '행정')
    elif '프로그' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '프로그')
    elif '트럭' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '트럭')        
    elif '택시' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '택시')
    elif '컴퓨터' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '컴퓨터')    
    elif '출판' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '출판')        
    elif '주방' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '주방')

    elif '건물' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '건물')
    elif '그래픽' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '그래픽')
    elif '공무원' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '공무원')
    elif '광고' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '광고')        
    elif '구두' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '구두')
    elif '금융' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '금융')    
    elif '기계조' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '기계조')        
    elif '학생' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '학생')
    elif '마케' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '마케')
    elif '물류' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '물류')
    elif '미술' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '미술')
    elif '방송' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '방송')        
    elif '배달' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '배달')
    elif '보일러' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '보일러')    
    elif '사진' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '사진')        
    elif '신문' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '신문')
    elif '여행' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '여행')
    elif '용접' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '용접')
    elif '웨딩' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '웨딩')
    elif '배달' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '배달')
    elif '음식' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '음식')        
    elif '배달' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '배달')
    elif '의류' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '의류')    
    elif '은행' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '은행')        
    elif '전기' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '전기공')
        
    elif '촬영' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '촬영')
    elif '카메라' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '촬영')
    elif '택배' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '택배')        
    elif '해군' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '해군')
    elif '호텔' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '호텔')    
    elif '휴대폰' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '휴대폰')        
    elif '회사' in values:
        test_2018['bq31'] = test_2018['bq31'].str.replace(values, '회사')
# Out:
# 100%|██████████| 9069/9069 [00:52<00:00, 171.90it/s]

# %%
for col in train_2018['bq31'].value_counts().loc[train_2018['bq31'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq31'] == col, 'bq31' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq31'].value_counts().index) - set(train_2018['bq31'].value_counts().loc[train_2018['bq31'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq31'] == col, 'bq31_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq32'] = train_2018['bq32'].astype(str)

train_2018['bq32'] = train_2018['bq32'].str.replace(' ', '')
train_2018['bq32'] = train_2018['bq32'].str.replace(')', '')
train_2018['bq32'] = train_2018['bq32'].str.replace('(', '')
train_2018['bq32'] = train_2018['bq32'].str.replace(',', '')
train_2018['bq32'] = train_2018['bq32'].str.replace('+', '')
train_2018['bq32'] = train_2018['bq32'].str.replace('모름', '없음')
train_2018['bq32'] = train_2018['bq32'].str.replace('없다', '없음')

# %%
for values in tqdm(train_2018['bq32']):
    if '주부' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '주부')
    elif '군인' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '군인')
    elif '사무원' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '사무직')
    elif '사무직' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '사무직')        
    elif '선장' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '항해사')
    elif '영업' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '영업')
    elif '판매' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '판매')
    elif '경리' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '경리')        
    elif '강사' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '강사')
    elif '교수' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '교수')    
    elif '서비스' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '서비스')
    elif '주부' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '주부')
    elif '군인' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '군인')
    elif '사무원' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '사무직')
    elif '사무직' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '사무직')        
    elif '선장' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '항해사')
    elif '영업' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '영업')
    elif '판매' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '판매')
    elif '경리' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '경리')        
    elif '강사' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '강사')
    elif '교수' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '교수')    
    elif '서비스' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '서비스')  

    elif 'IT' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, 'IT')
    elif '가구' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '가구')
    elif '간호' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '간호')        
    elif '개발' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '개발')
    elif '건설' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '건설')
    elif '건축' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '건축')
    elif '교사' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '교사')        
    elif '금속가공' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '금속가공')
    elif '동일' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '동일')    
    elif '미용' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '미용')  
    elif '버스' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '버스')
    elif '보험' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '보험')
    elif '사무' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '사무')        
    elif '생산' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '생산')
    elif '선생' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '교사')
    elif '섬유' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '섬유')
    elif '식당' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '식당')        
    elif '신발' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '신발')
    elif '없음' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '없음')    
    elif '연구' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '연구')  
        
    elif '외식' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '식당')        
    elif '유통' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '유통')
    elif '음악' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '음악')
    elif '인테리어' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '인테리어')
    elif '자동차' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '자동차')        
    elif '제조업' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '제조업')
    elif '초등' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '초등')    
    elif '회사원' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '회사원') 
        
    elif '회계' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '회계')
    elif '행정' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '행정')
    elif '프로그' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '프로그')
    elif '트럭' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '트럭')        
    elif '택시' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '택시')
    elif '컴퓨터' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '컴퓨터')    
    elif '출판' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '출판')        
    elif '주방' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '주방')
        
    elif '학원' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '학원')        
    elif '컨설' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '컨설')
    elif '축구' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '축구')    
    elif '의류' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '의류')        
    elif '의료' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '의료')
        
    elif '요양' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '요양')
    elif '식품' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '식품')    
    elif '선박' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '선박')        
    elif '방송' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '방송')
        
    elif '미술' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '미술')
    elif '물리치료' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '물리치료')    
    elif '무대' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '무대')        
    elif '마케' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '마케')
        
    elif '교육' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '교육')
    elif '공인중개' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '공인중개')    
    elif '경비' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '경비')        
    elif '감독' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '감독')
    elif '병원' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '병원')

    elif '감리' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '감리')
    elif '개인사업' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '개인사업')    
    elif '경찰' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '경찰')        
    elif '공공기관' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '공공기관')
    elif '공무원' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '공무원')
    elif '공연' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '공연')    
    elif '관광' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '관광')        
    elif '광고' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '광고')
    elif '그래픽' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '그래픽')
        
    elif '데이터' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '데이터')
    elif '동물' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '동물')    
    elif '동종업' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '동종업')        
    elif '드론' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '드론')
    elif '무역' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '무역')
    elif '문화재' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '문화재')    
    elif '헬기' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '헬기')        
    elif '배달' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '배달')
    elif '배관' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '배관')        
        
    elif '변호사' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '변호사')
    elif '보건' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '병원')    
    elif '보안' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '보안')        
    elif '부동산' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '부동산')
    elif '사회복지' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '사회복지')
    elif '소방' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '소방')    
    elif '소설' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '소설')        
    elif '애견' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '애견')
    elif '어린이집' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '어린이')        
    elif '여행' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '여행')    
    elif '영상' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '영상')        
    elif '웨딩' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '웨딩')
    elif '일러스트' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '일러스트')
    elif '전기안전' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '전기안전')    
    elif '조경' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '조경')        
    elif '환경' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '환경')
    elif '홍보' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '홍보')   
        
    elif '호텔' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '호텔')        
    elif '한식' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '한식')
    elif '품질' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '품질')
    elif '패션' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '패션')    
    elif '통역가' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '통역사')        
    elif '택배' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '택배')
    elif '캐드' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, 'CAD')   
        
    elif '청소년상담' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '청소년상담')
    elif '철도' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '철도')    
    elif '제약회사' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '제약회사')        
    elif '택배' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, '택배')
    elif '캐드' in values:
        train_2018['bq32'] = train_2018['bq32'].str.replace(values, 'CAD')
# Out:
# 100%|██████████| 9072/9072 [00:57<00:00, 158.49it/s]

# %%
for col in train_2018['bq32'].value_counts().loc[train_2018['bq32'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq32'] == col, 'bq32' + col] = 1
    train_2018 = train_2018.fillna(0)         

for col in train_2018['bq32'].value_counts().loc[train_2018['bq32'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq32'] == col, 'bq32_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq32'] = test_2018['bq32'].astype(str)

test_2018['bq32'] = test_2018['bq32'].str.replace(' ', '')
test_2018['bq32'] = test_2018['bq32'].str.replace(')', '')
test_2018['bq32'] = test_2018['bq32'].str.replace('(', '')
test_2018['bq32'] = test_2018['bq32'].str.replace('모름', '없음')
test_2018['bq32'] = test_2018['bq32'].str.replace('없다', '없음')
test_2018['bq32'] = test_2018['bq32'].str.replace('님', '')
test_2018['bq32'] = test_2018['bq32'].str.replace('+', '')

# %%
for values in tqdm(test_2018['bq32']):
    if '주부' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '주부')
    elif '군인' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '군인')
    elif '사무원' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '사무직')
    elif '사무직' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '사무직')        
    elif '선장' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '항해사')
    elif '영업' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '영업')
    elif '판매' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '판매')
    elif '경리' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '경리')        
    elif '강사' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '강사')
    elif '교수' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '교수')    
    elif '서비스' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '서비스')
    elif '주부' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '주부')
    elif '군인' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '군인')
    elif '사무원' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '사무직')
    elif '사무직' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '사무직')        
    elif '선장' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '항해사')
    elif '영업' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '영업')
    elif '판매' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '판매')
    elif '경리' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '경리')        
    elif '강사' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '강사')
    elif '교수' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '교수')    
    elif '서비스' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '서비스')  

    elif 'IT' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, 'IT')
    elif '가구' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '가구')
    elif '간호' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '간호')        
    elif '개발' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '개발')
    elif '건설' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '건설')
    elif '건축' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '건축')
    elif '교사' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '교사')        
    elif '금속가공' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '금속가공')
    elif '동일' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '동일')    
    elif '미용' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '미용')  
    elif '버스' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '버스')
    elif '보험' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '보험')
    elif '사무' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '사무')        
    elif '생산' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '생산')
    elif '선생' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '교사')
    elif '섬유' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '섬유')
    elif '식당' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '식당')        
    elif '신발' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '신발')
    elif '없음' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '없음')    
    elif '연구' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '연구')  
        
    elif '외식' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '식당')        
    elif '유통' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '유통')
    elif '음악' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '음악')
    elif '인테리어' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '인테리어')
    elif '자동차' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '자동차')        
    elif '제조업' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '제조업')
    elif '초등' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '초등')    
    elif '회사원' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '회사원') 
        
    elif '회계' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '회계')
    elif '행정' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '행정')
    elif '프로그' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '프로그')
    elif '트럭' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '트럭')        
    elif '택시' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '택시')
    elif '컴퓨터' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '컴퓨터')    
    elif '출판' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '출판')        
    elif '주방' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '주방')
        
    elif '학원' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '학원')        
    elif '컨설' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '컨설')
    elif '축구' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '축구')    
    elif '의류' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '의류')        
    elif '의료' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '의료')
        
    elif '요양' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '요양')
    elif '식품' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '식품')    
    elif '선박' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '선박')        
    elif '방송' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '방송')
        
    elif '미술' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '미술')
    elif '물리치료' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '물리치료')    
    elif '무대' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '무대')        
    elif '마케' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '마케')
        
    elif '교육' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '교육')
    elif '공인중개' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '공인중개')    
    elif '경비' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '경비')        
    elif '감독' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '감독')
    elif '병원' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '병원')

    elif '감리' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '감리')
    elif '개인사업' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '개인사업')    
    elif '경찰' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '경찰')        
    elif '공공기관' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '공공기관')
    elif '공무원' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '공무원')
    elif '공연' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '공연')    
    elif '관광' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '관광')        
    elif '광고' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '광고')
    elif '그래픽' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '그래픽')
        
    elif '데이터' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '데이터')
    elif '동물' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '동물')    
    elif '동종업' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '동종업')        
    elif '드론' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '드론')
    elif '무역' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '무역')
    elif '문화재' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '문화재')    
    elif '헬기' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '헬기')        
    elif '배달' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '배달')
    elif '배관' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '배관')        
        
    elif '변호사' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '변호사')
    elif '보건' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '병원')    
    elif '보안' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '보안')        
    elif '부동산' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '부동산')
    elif '사회복지' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '사회복지')
    elif '소방' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '소방')    
    elif '소설' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '소설')        
    elif '애견' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '애견')
    elif '어린이집' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '어린이')        
    elif '여행' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '여행')    
    elif '영상' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '영상')        
    elif '웨딩' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '웨딩')
    elif '일러스트' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '일러스트')
    elif '전기안전' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '전기안전')    
    elif '조경' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '조경')        
    elif '환경' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '환경')
    elif '홍보' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '홍보')   
        
    elif '호텔' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '호텔')        
    elif '한식' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '한식')
    elif '품질' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '품질')
    elif '패션' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '패션')    
    elif '통역가' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '통역사')        
    elif '택배' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '택배')
    elif '캐드' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, 'CAD')   
        
    elif '청소년상담' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '청소년상담')
    elif '철도' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '철도')    
    elif '제약회사' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '제약회사')        
    elif '택배' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, '택배')
    elif '캐드' in values:
        test_2018['bq32'] = test_2018['bq32'].str.replace(values, 'CAD')
# Out:
# 100%|██████████| 9069/9069 [00:47<00:00, 190.60it/s]

# %%
for col in train_2018['bq32'].value_counts().loc[train_2018['bq32'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq32'] == col, 'bq32' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq32'].value_counts().index) - set(train_2018['bq32'].value_counts().loc[train_2018['bq32'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq32'] == col, 'bq32_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq33'] = train_2018['bq33'].astype(str)

train_2018['bq33'] = train_2018['bq33'].str.replace(' ', '')
train_2018['bq33'] = train_2018['bq33'].str.replace(')', '')
train_2018['bq33'] = train_2018['bq33'].str.replace('(', '')
train_2018['bq33'] = train_2018['bq33'].str.replace(',', '')
train_2018['bq33'] = train_2018['bq33'].str.replace('+', '')
train_2018['bq33'] = train_2018['bq33'].str.replace('모름', '없음')
train_2018['bq33'] = train_2018['bq33'].str.replace('없다', '없음')

train_2018['bq33'] = train_2018['bq33'].str.replace('1', '없음')
train_2018['bq33'] = train_2018['bq33'].str.replace('2', '없음')
train_2018['bq33'] = train_2018['bq33'].str.replace('3', '없음')
train_2018['bq33'] = train_2018['bq33'].str.replace('4', '없음')
train_2018['bq33'] = train_2018['bq33'].str.replace('5', '없음')

# %%
for values in tqdm(train_2018['bq33']):
    if '유투' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '유튜버')
    elif '잘모르겠음' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '없음')
    elif '드론' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '드론')
    elif '데이터' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '데이터')
    elif 'AI' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '데이터')
    elif '크리에이터' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '유튜버')
    elif '유튜' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '유튜버')   
    elif '1인' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '유튜버')
    elif '3D프린' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '3D프린')
    elif '디자인' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '디자인')
    elif '무대' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '무대')
    elif '스포츠심리' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '스포츠심리')
    elif '자산' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '자산')   
        
    elif '승무원' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '승무원')
    elif '3D프린' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '3D프린')
    elif '한방' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '한방')
    elif '프로그' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '프로그')
    elif '분석가' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '데이터')        
    elif '4차' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '4차')
    elif 'VR' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '4차')
    elif '가상' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '4차')
    elif '개인방송' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '유튜버')
    elif '대리운전' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '대리운전')   
    elif '신재생' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '신재생')
    elif '인공지능' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '데이터')
    elif '증강현실' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '4차')
    elif '태양광' in values:
        train_2018['bq33'] = train_2018['bq33'].str.replace(values, '태양광')
# Out:
# 100%|██████████| 9072/9072 [00:01<00:00, 7846.26it/s]

# %%
for col in train_2018['bq33'].value_counts().loc[train_2018['bq33'].value_counts() >= 3].index:
    train_2018.loc[train_2018['bq33'] == col, 'bq33' + col] = 1
    train_2018 = train_2018.fillna(0)         

for col in train_2018['bq33'].value_counts().loc[train_2018['bq33'].value_counts() < 3].index:
    train_2018.loc[train_2018['bq33'] == col, 'bq33_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq33'] = test_2018['bq33'].astype(str)

test_2018['bq33'] = test_2018['bq33'].str.replace(' ', '')
test_2018['bq33'] = test_2018['bq33'].str.replace(')', '')
test_2018['bq33'] = test_2018['bq33'].str.replace('(', '')
test_2018['bq33'] = test_2018['bq33'].str.replace('모름', '없음')
test_2018['bq33'] = test_2018['bq33'].str.replace('없다', '없음')
test_2018['bq33'] = test_2018['bq33'].str.replace('님', '')
test_2018['bq33'] = test_2018['bq33'].str.replace('+', '')

# %%
for values in tqdm(test_2018['bq33']):
    if '유투' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '유튜버')
    elif '잘모르겠음' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '없음')
    elif '드론' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '드론')
    elif '데이터' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '데이터')
    elif 'AI' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '데이터')
    elif '크리에이터' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '유튜버')
    elif '유튜' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '유튜버')   
    elif '1인' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '유튜버')
    elif '3D프린' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '3D프린')
    elif '디자인' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '디자인')
    elif '무대' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '무대')
    elif '스포츠심리' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '스포츠심리')
    elif '자산' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '자산')   
        
    elif '승무원' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '승무원')
    elif '3D프린' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '3D프린')
    elif '한방' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '한방')
    elif '프로그' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '프로그')
    elif '분석가' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '데이터')        
    elif '4차' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '4차')
    elif 'VR' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '4차')
    elif '가상' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '4차')
    elif '개인방송' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '유튜버')
    elif '대리운전' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '대리운전')   
    elif '신재생' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '신재생')
    elif '인공지능' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '데이터')
    elif '증강현실' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '4차')
    elif '태양광' in values:
        test_2018['bq33'] = test_2018['bq33'].str.replace(values, '태양광')
# Out:
# 100%|██████████| 9069/9069 [00:01<00:00, 7365.29it/s]

# %%
for col in train_2018['bq33'].value_counts().loc[train_2018['bq33'].value_counts() >= 3].index:
    test_2018.loc[test_2018['bq33'] == col, 'bq33' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq33'].value_counts().index) - set(train_2018['bq33'].value_counts().loc[train_2018['bq33'].value_counts() >= 3].index):
    test_2018.loc[test_2018['bq33'] == col, 'bq33_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(' ', '')
train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(')', '')
train_2018['bq37_1'] = train_2018['bq37_1'].str.replace('(', '')
train_2018['bq37_1'] = train_2018['bq37_1'].str.replace('모름', '없음')
train_2018['bq37_1'] = train_2018['bq37_1'].str.replace('없다', '없음')

train_2018['bq37_1'] = train_2018['bq37_1'].str.replace('학', '')
train_2018['bq37_1'] = train_2018['bq37_1'].str.replace('과', '')

# %%
for values in tqdm(train_2018['bq37_1']):
    if '인문' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '인문')
    elif '경영' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '경영')
    elif '기계' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '기계')
    elif '문과' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '문')
    elif '이과' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '이')
    elif '컴퓨터' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '컴퓨터')
    elif '전기' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '전기')
    elif '건축' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '건축')
    elif '화학' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '화학')
    elif '환경' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '환경')      
    elif '행정' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '행정')
    elif '경제' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '경제')
    elif '컴퓨터' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '컴퓨터')
    elif '전자' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '전자')
    elif '토목' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '토목')
    elif '사회' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '사회')
    elif '의예' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '의학')   
    elif '간호' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '간호')
    elif '정보통신' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '정보통신')
    elif '토목' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '토목')
    elif '영문' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '영문')
    elif '디자인' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '디자인')       
    elif '의학' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '의학')   
    elif '유아' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '유아')
    elif '철학' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '철학')
    elif '세무' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '경제')
    elif '회계' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '경제')     
    elif '신문' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '신문')
    elif '식품' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '식품')
    elif '국어' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '국어')
    elif '연극' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '연극')  

    elif '건설' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '건설')       
    elif '경찰' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '경찰')   
    elif '관광' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '관광')
    elif '광고' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '광고')
    elif '심리' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '심리')
    elif '금속' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '금속')     
    elif '금융' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '금융')
    elif '농업' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '농업')
    elif '동물' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '동물')
    elif '메이크업' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '메이크업')  
    elif '문화' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '문화')       
    elif '미디어' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '미디어')   
    elif '방송' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '방송')
    elif '상업' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '상업')
    elif '소프트웨' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '소프트웨')
    elif '스포츠' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '스포츠')     
    elif '실업계' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '실업계')
    elif '언어치료' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '언어치료')
    elif '일본' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '일본')
    elif '자동차' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '자동차')  
    elif '조리' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '조리')       
    elif '지리' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '지리')   
    elif '체육' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '체육')
    elif '초등' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '초등')
    elif '통신' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '통신')
    elif '특수' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '특수')     
    elif '항공' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '항공')
    elif '호텔' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '호텔')
    elif '화공' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '화공')
    elif '해양산' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '해양산')  

    elif '공업' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '공업')   
    elif '마케팅' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '마케팅')
    elif '문예' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '문예')
    elif '미술' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '미술')
    elif '보건' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '보건')     
    elif '사진' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '사진')
    elif '생물' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '생물')
    elif '생명' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '생물')
    elif '소방' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '소방')  
        
    elif '수산' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '수산')
    elif '스페인어' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '스페인어')
    elif '실업' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '실업')     
    elif '아동' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '아동')
    elif '영상' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '영상')
    elif '유통' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '유통')
    elif '음악' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '음악')  
    elif '의료' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '의료')
    elif '이공' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '이공')
    elif '일어' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '일어')     
    elif '일본' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '일어')
    elif '제어' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '제어')
    elif '중국' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '중국')
    elif '청소년' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '청소년')       
    elif '프랑스' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '프랑스')  
    elif '피부' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '피부')
    elif '해양수' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '해양수')
    elif '해양생' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '해양생')     

    elif '가정' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '가정')     
    elif '공고' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '공고')
    elif '교통' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '교통')
    elif '도시' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '도시')
    elif '뷰티' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '뷰티')       
    elif '해상운송' in values:
        train_2018['bq37_1'] = train_2018['bq37_1'].str.replace(values, '해상운송')
# Out:
# 100%|██████████| 9072/9072 [00:33<00:00, 273.06it/s]

# %%
for col in train_2018['bq37_1'].value_counts().loc[train_2018['bq37_1'].value_counts() >= 4].index:
    train_2018.loc[train_2018['bq37_1'] == col, 'bq37_1' + col] = 1
    train_2018 = train_2018.fillna(0)         

for col in train_2018['bq37_1'].value_counts().loc[train_2018['bq37_1'].value_counts() < 4].index:
    train_2018.loc[train_2018['bq37_1'] == col, 'bq37_1_unknown'] = 1
    train_2018 = train_2018.fillna(0)

# %%
test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(' ', '')
test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(')', '')
test_2018['bq37_1'] = test_2018['bq37_1'].str.replace('(', '')
test_2018['bq37_1'] = test_2018['bq37_1'].str.replace('모름', '없음')
test_2018['bq37_1'] = test_2018['bq37_1'].str.replace('없다', '없음')

test_2018['bq37_1'] = test_2018['bq37_1'].str.replace('학', '')
test_2018['bq37_1'] = test_2018['bq37_1'].str.replace('과', '')

# %%
for values in tqdm(test_2018['bq37_1']):
    if '인문' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '인문')
    elif '경영' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '경영')
    elif '기계' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '기계')
    elif '문과' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '문')
    elif '이과' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '이')
    elif '컴퓨터' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '컴퓨터')
    elif '전기' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '전기')
    elif '건축' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '건축')
    elif '화학' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '화학')
    elif '환경' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '환경')      
    elif '행정' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '행정')
    elif '경제' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '경제')
    elif '컴퓨터' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '컴퓨터')
    elif '전자' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '전자')
    elif '토목' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '토목')
    elif '사회' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '사회')
    elif '의예' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '의학')   
    elif '간호' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '간호')
    elif '정보통신' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '정보통신')
    elif '토목' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '토목')
    elif '영문' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '영문')
    elif '디자인' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '디자인')       
    elif '의학' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '의학')   
    elif '유아' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '유아')
    elif '철학' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '철학')
    elif '세무' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '경제')
    elif '회계' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '경제')     
    elif '신문' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '신문')
    elif '식품' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '식품')
    elif '국어' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '국어')
    elif '연극' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '연극')  

    elif '건설' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '건설')       
    elif '경찰' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '경찰')   
    elif '관광' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '관광')
    elif '광고' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '광고')
    elif '심리' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '심리')
    elif '금속' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '금속')     
    elif '금융' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '금융')
    elif '농업' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '농업')
    elif '동물' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '동물')
    elif '메이크업' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '메이크업')  
    elif '문화' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '문화')       
    elif '미디어' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '미디어')   
    elif '방송' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '방송')
    elif '상업' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '상업')
    elif '소프트웨' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '소프트웨')
    elif '스포츠' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '스포츠')     
    elif '실업계' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '실업계')
    elif '언어치료' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '언어치료')
    elif '일본' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '일본')
    elif '자동차' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '자동차')  
    elif '조리' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '조리')       
    elif '지리' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '지리')   
    elif '체육' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '체육')
    elif '초등' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '초등')
    elif '통신' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '통신')
    elif '특수' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '특수')     
    elif '항공' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '항공')
    elif '호텔' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '호텔')
    elif '화공' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '화공')
    elif '해양산' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '해양산')  

    elif '공업' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '공업')   
    elif '마케팅' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '마케팅')
    elif '문예' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '문예')
    elif '미술' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '미술')
    elif '보건' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '보건')     
    elif '사진' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '사진')
    elif '생물' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '생물')
    elif '생명' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '생물')
    elif '소방' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '소방')  
        
    elif '수산' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '수산')
    elif '스페인어' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '스페인어')
    elif '실업' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '실업')     
    elif '아동' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '아동')
    elif '영상' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '영상')
    elif '유통' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '유통')
    elif '음악' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '음악')  
    elif '의료' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '의료')
    elif '이공' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '이공')
    elif '일어' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '일어')     
    elif '일본' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '일어')
    elif '제어' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '제어')
    elif '중국' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '중국')
    elif '청소년' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '청소년')       
    elif '프랑스' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '프랑스')  
    elif '피부' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '피부')
    elif '해양수' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '해양수')
    elif '해양생' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '해양생')     
        
    elif '가정' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '가정')     
    elif '공고' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '공고')
    elif '교통' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '교통')
    elif '도시' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '도시')
    elif '뷰티' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '뷰티')       
    elif '해상운송' in values:
        test_2018['bq37_1'] = test_2018['bq37_1'].str.replace(values, '해상운송')
# Out:
# 100%|██████████| 9069/9069 [00:33<00:00, 268.63it/s]

# %%
for col in train_2018['bq37_1'].value_counts().loc[train_2018['bq37_1'].value_counts() >= 4].index:
    test_2018.loc[test_2018['bq37_1'] == col, 'bq37_1' + col] = 1
    test_2018 = test_2018.fillna(0)

for col in set(test_2018['bq37_1'].value_counts().index) - set(train_2018['bq37_1'].value_counts().loc[train_2018['bq37_1'].value_counts() >= 4].index):
    test_2018.loc[test_2018['bq37_1'] == col, 'bq37_1_unknown'] = 1
    test_2018 = test_2018.fillna(0)

# %%
train_2018 = train_2018.drop(train_2018.select_dtypes(object).columns, axis = 1)
test_2018 = test_2018.drop(test_2018.select_dtypes(object).columns, axis = 1)

# %%
train_2018.to_csv('Data/train/2.FeatureEngineering_train_2018.csv', index = False)
test_2018.to_csv('Data/test/2.FeatureEngineering_test_2018.csv', index = False)
